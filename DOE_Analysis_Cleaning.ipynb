# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# %%
#import all DataFrames
attendance_cost_df = pd.read_csv('CSVs_unclean/attendance_cost_unclean.csv', index_col=0)
retention_rate_df = pd.read_csv('CSVs_unclean/retention_unclean.csv', index_col=0)
student_demo_df = pd.read_csv('CSVs_unclean/student_demo_unclean.csv', index_col=0)
student_gen_df = pd.read_csv('CSVs_unclean/student_gen_unclean.csv', index_col=0)
student_income_df = pd.read_csv('CSVs_unclean/student_income_unclean.csv', index_col=0)
student_sex_df = pd.read_csv('CSVs_unclean/student_sex_unclean.csv', index_col=0)
school_roots_df = pd.read_csv('CSVs_unclean/school_roots_unclean.csv', index_col=0)

# %%
student_demo_df = student_demo_df.drop(columns=['latest.school.region_id',
                                       'latest.school.religious_affiliation',
                                      'latest.student.demographics.race_ethnicity.api_2000'])

#Renaming columns
student_demo_df = student_demo_df.rename(columns={'latest.school.name': 'school name',
                                                  'location.lat': 'latitude',
                                                  'location.lon': 'longitude',
                                                  'latest.school.zip': 'zipcode',
                                                  'latest.student.size':'student size',
                                                  'latest.aid.pell_grant_rate': 'pell grant rate',
                                                  'latest.school.faculty_salary': 'average faculty salary',
                                                  'latest.school.ft_faculty_rate': 'fulltime faculty rate',
                                                  'latest.admissions.test_requirements':'admission test requirements',
                                                  'latest.completion.completion_rate_4yr_150_aian': 'completion rate in 4 years (american indian)',
                                                  'latest.completion.completion_rate_4yr_150_asian': 'completion rate in 4 years (asian)',
                                                  'latest.completion.completion_rate_4yr_150_nhpi': 'completion rate in 4 years (hawaiian or pacific islander)',
                                                  'latest.completion.completion_rate_4yr_150_hispanic': 'completion rate in 4 years (hispanic)',
                                                  'latest.completion.completion_rate_4yr_150_black': 'completion rate in 4 years (black)',
                                                  'latest.completion.completion_rate_4yr_150_white': 'completion rate in 4 years (white)',
                                                  'latest.student.demographics.race_ethnicity.white': 'total student demographic (white)',
                                                  'latest.student.demographics.race_ethnicity.hispanic': 'total student demographic (hispanic)',
                                                  'latest.student.demographics.race_ethnicity.black': 'total student demographic (black)',
                                                  'latest.student.demographics.race_ethnicity.aian': 'total student demographic (american indian)',
                                                  'latest.student.demographics.women': 'total student demographic (female)',
                                                  'latest.student.demographics.men': 'total student demographic (male)',
                                                  'latest.aid.median_debt.income.0_30000': 'median debt for income 0-30000',
                                                  'latest.aid.median_debt.income.30001_75000': 'median debt for income 30001_75000',
                                                  'latest.aid.median_debt.income.greater_than_75000': 'median debt for income greater than 75000',
                                                  'latest.aid.median_debt.noncompleters': 'median debt for noncompleters',
                                                  'latest.aid.median_debt.completers.overall': 'median debt for completers',
                                                  'latest.aid.median_debt.male_students': 'median debt for male students',
                                                  'latest.aid.median_debt.female_students': 'median debt for female students',
                                                  'latest.aid.median_debt.independent_students': 'median debt for independent students',
                                                  'latest.aid.median_debt.dependent_students': 'median debt for dependent students',
                                                  'latest.student.demographics.faculty.race_ethnicity.white': 'faculty demographic (white)',
                                                  'latest.student.demographics.faculty.race_ethnicity.two_or_more': 'faculty demographic (2 or more race or ethnicity)',
                                                  'latest.student.demographics.faculty.race_ethnicity.unknown': 'faculty demographic (unknown race or ethnicity)',
                                                  'latest.student.demographics.faculty.race_ethnicity.nhpi': 'faculty demographic (hawaiian or pacific islander)',
                                                  'latest.student.demographics.faculty.race_ethnicity.hispanic': 'faculty demographic (hispanic)',
                                                  'latest.student.demographics.faculty.race_ethnicity.black': 'faculty demographic (black)',
                                                  'latest.student.demographics.faculty.race_ethnicity.asian': 'faculty demographic (asian)',
                                                  'latest.student.demographics.faculty.race_ethnicity.aian': 'faculty demographic (american indian)',
                                                  'latest.student.share_25_older': 'undergrads aged 25 or older'
                                                  }, inplace=False)

#Filling NAs and re-arranging columns
# student_demo_df = student_demo_df.fillna(0)

pd.set_option('display.max_columns', None)

# %%
student_demo_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
student_demo_df = student_demo_df.drop_duplicates(subset='school name')
student_demo_df = student_demo_df.set_index('school name')
student_demo_df = student_demo_df.fillna(0)
student_demo_df
# Out:
#                                                        zipcode  student size  \
# school name
# Alabama A & M University                                 35762        5098.0
# University of Alabama at Birmingham                 35294-0110       13284.0
# Amridge University                                  36117-3553         251.0
# University of Alabama in Huntsville                      35899        7358.0
# Alabama State University                            36104-0271        3495.0
# ...                                                        ...           ...
# Universal Technical Institute-West Texas            78753-9742           0.0
# Avalon Institute-Las Vegas                          89102-0046         170.0
# Medspa Academies-National Institute of Modern A...  89169-6745          97.0
# American Institute-Cherry Hill                      08002-4309          83.0
# Glendale Career College-North-West College-Bake...  93304-5075          36.0
#
# ...

# %%
#convert to cleaned csv and json
student_demo_df.to_csv('CSVs/student_demo.csv')
student_demo_df.to_json('JSONs/student_demo.json', orient = 'index', compression = 'infer', index = 'true')

# %%
student_income_df = student_income_df.rename(columns={'latest.school.name': 'school name',
                                                      'location.lat': 'latitude',
                                                      'location.lon': 'longitude',
                                                      'latest.student.demographics.median_family_income': 'student median family income',
                                                      'latest.completion.title_iv.low_inc.completed_by.3yrs': 't9 low inc comp by 3y',
                                                      'latest.completion.title_iv.low_inc.completed_by.4yrs': 't9 low inc comp by 4y',
                                                      'latest.completion.title_iv.low_inc.completed_by.6yrs': 't9 low inc comp by 6y',
                                                      'latest.completion.title_iv.low_inc.completed_by.8yrs': 't9 low inc comp by 8y',
                                                      'latest.completion.title_iv.low_inc.withdrawn_by.2yrs': 't9 low inc withdr by 2y',
                                                      'latest.completion.title_iv.low_inc.withdrawn_by.3yrs': 't9 low inc withdr by 3y',
                                                      'latest.completion.title_iv.low_inc.withdrawn_by.4yrs': 't9 low inc withdr by 4y',
                                                      'latest.completion.title_iv.low_inc.withdrawn_by.6yrs': 't9 low inc withdr by 6y',
                                                      'latest.completion.title_iv.low_inc.withdrawn_by.8yrs': 't9 low inc withdr by 8y',
                                                      'latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.2yrs': 't9 low inc transfers withdr by 2y',
                                                      'latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.3yrs': 't9 low inc transfers withdr by 3y',
                                                      'latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.4yrs': 't9 low inc transfers withdr by 4y',
                                                      'latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.6yrs': 't9 low inc transfers withdr by 6y',
                                                      'latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.8yrs': 't9 low inc transfers withdr by 8y',  
                                                      'latest.completion.title_iv.low_inc.transf_completed_4yr_by.2yrs': 't9 low inc transfers comp by 2y',
                                                      'latest.completion.title_iv.low_inc.transf_completed_4yr_by.3yrs': 't9 low inc transfers comp by 3y',
                                                      'latest.completion.title_iv.low_inc.transf_completed_4yr_by.4yrs': 't9 low inc transfers comp by 4y',
                                                      'latest.completion.title_iv.low_inc.transf_completed_4yr_by.6yrs': 't9 low inc transfers comp by 6y',
                                                      'latest.completion.title_iv.low_inc.transf_completed_4yr_by.8yrs': 't9 low inc transfers comp by 8y',
                                                      
                                                      'latest.completion.title_iv.mid_inc.completed_by.2yrs': 't9 middle inc comp by 2y',
                                                      'latest.completion.title_iv.mid_inc.completed_by.3yrs': 't9 middle inc comp by 3y',
                                                      'latest.completion.title_iv.mid_inc.completed_by.4yrs': 't9 middle inc comp by 4y',
                                                      'latest.completion.title_iv.mid_inc.completed_by.6yrs': 't9 middle inc comp by 6y',
                                                      'latest.completion.title_iv.mid_inc.completed_by.8yrs': 't9 middle inc comp by 8y',
                                                      'latest.completion.title_iv.mid_inc.withdrawn_by.2yrs': 't9 middle inc withdr by 2y',
                                                      'latest.completion.title_iv.mid_inc.withdrawn_by.3yrs': 't9 middle inc withdr by 3y',
                                                      'latest.completion.title_iv.mid_inc.withdrawn_by.4yrs': 't9 middle inc withdr by 4y',
                                                      'latest.completion.title_iv.mid_inc.withdrawn_by.6yrs': 't9 middle inc withdr by 6y',
                                                      'latest.completion.title_iv.mid_inc.withdrawn_by.8yrs': 't9 middle inc withdr by 8y',
                                                      'latest.completion.title_iv.mid_inc.transf_withdrawn_4yr_by.2yrs': 't9 middle inc transfers withdr by 2y',
                                                      'latest.completion.title_iv.mid_inc.transf_withdrawn_4yr_by.3yrs': 't9 middle inc transfers withdr by 3y',
                                                      'latest.completion.title_iv.mid_inc.transf_withdrawn_4yr_by.4yrs': 't9 middle inc transfers withdr by 4y',
                                                      'latest.completion.title_iv.mid_inc.transf_withdrawn_4yr_by.6yrs': 't9 middle inc transfers withdr by 6y',
                                                      'latest.completion.title_iv.mid_inc.transf_withdrawn_4yr_by.8yrs': 't9 middle inc transfers withdr by 8y',
                                                      'latest.completion.title_iv.mid_inc.transf_completed_4yr_by.2yrs': 't9 middle inc transfers comp by 2y',
                                                      'latest.completion.title_iv.mid_inc.transf_completed_4yr_by.3yrs': 't9 middle inc transfers comp by 3y',
                                                      'latest.completion.title_iv.mid_inc.transf_completed_4yr_by.4yrs': 't9 middle inc transfers comp by 4y',
                                                      'latest.completion.title_iv.mid_inc.transf_completed_4yr_by.6yrs': 't9 middle inc transfers comp by 6y',
                                                      'latest.completion.title_iv.mid_inc.transf_completed_4yr_by.8yrs': 't9 middle inc transfers comp by 8y',
                                                      
                                                      'latest.completion.title_iv.high_inc.completed_by.2yrs': 't9 high inc completed by 2y',
                                                      'latest.completion.title_iv.high_inc.completed_by.3yrs': 't9 high inc completed by 3y',
                                                      'latest.completion.title_iv.high_inc.completed_by.4yrs': 't9 high inc completed by 4y',
                                                      'latest.completion.title_iv.high_inc.completed_by.6yrs': 't9 high inc completed by 6y',
                                                      'latest.completion.title_iv.high_inc.completed_by.8yrs': 't9 high inc completed by 8y',
                                                      'latest.completion.title_iv.high_inc.withdrawn_by.2yrs': 't9 high inc withdr by 2y',
                                                      'latest.completion.title_iv.high_inc.withdrawn_by.3yrs': 't9 high inc withdr by 3y',
                                                      'latest.completion.title_iv.high_inc.withdrawn_by.4yrs': 't9 high inc withdr by 4y',
                                                      'latest.completion.title_iv.high_inc.withdrawn_by.6yrs': 't9 high inc withdr by 6y',
                                                      'latest.completion.title_iv.high_inc.withdrawn_by.8yrs': 't9 high inc withdr by 8y',
                                                      'latest.completion.title_iv.high_inc.transf_withdrawn_4yr_by.2yrs': 't9 high inc transfers withdr by 2y',
                                                      'latest.completion.title_iv.high_inc.transf_withdrawn_4yr_by.3yrs': 't9 high inc transfers withdr by 3y',
                                                      'latest.completion.title_iv.high_inc.transf_withdrawn_4yr_by.4yrs': 't9 high inc transfers withdr by 4y',
                                                      'latest.completion.title_iv.high_inc.transf_withdrawn_4yr_by.6yrs': 't9 high inc transfers withdr by 6y',
                                                      'latest.completion.title_iv.high_inc.transf_withdrawn_4yr_by.8yrs': 't9 high inc transfers withdr by 8y',
                                                      'latest.completion.title_iv.high_inc.transf_completed_4yr_by.2yrs': 't9 high inc transfers to 4y comp by 2y',
                                                      'latest.completion.title_iv.high_inc.transf_completed_4yr_by.3yrs': 't9 high inc transfers to 4y comp by 3y',
                                                      'latest.completion.title_iv.high_inc.transf_completed_4yr_by.4yrs': 't9 high inc transfers to 4y comp by 4y',
                                                      'latest.completion.title_iv.high_inc.transf_completed_4yr_by.6yrs': 't9 high inc transfers to 4y comp by 6y',
                                                      'latest.completion.title_iv.high_inc.transf_completed_4yr_by.8yrs': 't9 high inc transfers to 4y comp by 8y'
                                                   })
# student_income_df = student_income_df.fillna(0)
pd.set_option('display.max_columns', None)

# %%
student_income_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
student_income_df = student_income_df.drop_duplicates(subset='school name')
student_income_df = student_income_df.set_index('school name')
student_income_df = student_income_df.fillna(0)
student_income_df
# Out:
#                                                     student median family income  \
# school name
# Alabama A & M University                                                 23553.0
# University of Alabama at Birmingham                                      34489.0
# Amridge University                                                       15033.0
# University of Alabama in Huntsville                                      44787.0
# Alabama State University                                                 22080.0
# ...                                                                          ...
# Universal Technical Institute-West Texas                                 29403.0
# Avalon Institute-Las Vegas                                               23353.0
# Medspa Academies-National Institute of Modern A...                       31472.0
# American Institute-Cherry Hill                                           12000.0
# ...

# %%
#convert to cleaned csv and json
student_income_df.to_csv('CSVs/student_income.csv')
student_income_df.to_json('JSONs/student_income.json', orient = 'index', compression = 'infer', index = 'true')

# %%
student_sex_df = student_sex_df.rename(columns={'latest.school.name': 'school name',
                                                'location.lat': 'latitude',
                                                'location.lon': 'longitude',
                                                'latest.school.women_only': 'women only schools',
                                                'latest.school.men_only': 'men only schools',
                                                'latest.completion.title_iv.male.completed_by.2yrs': 'males compl t9 by 2y',
                                                'latest.completion.title_iv.male.completed_by.3yrs': 'males compl t9 by 3y',
                                                'latest.completion.title_iv.male.completed_by.4yrs': 'males compl t9 by 4y',
                                                'latest.completion.title_iv.male.completed_by.6yrs': 'males compl t9 by 6y',
                                                'latest.completion.title_iv.male.completed_by.8yrs': 'males compl t9 by 8y',
                                                'latest.completion.title_iv.male.withdrawn_by.2yrs': 'males withdr t9 by 2y',
                                                'latest.completion.title_iv.male.withdrawn_by.3yrs': 'males withdr t9 by 3y',
                                                'latest.completion.title_iv.male.withdrawn_by.4yrs': 'males withdr t9 by 4y',
                                                'latest.completion.title_iv.male.withdrawn_by.6yrs': 'males withdr t9 by 6y',
                                                'latest.completion.title_iv.male.withdrawn_by.8yrs': 'males withdr t9 by 8y',
                                                'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': 'male transfers withdr 4y by 2y',
                                                'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': 'male transfers withdr 4y by 3y',
                                                'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': 'male transfers withdr 4y by 4y',
                                                'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': 'male transfers withdr 4y by 6y',
                                                'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': 'male transfers withdr 4y by 8y',
                                                'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': 'male transfers compl in 4y by 2y',
                                                'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': 'male transfers compl in 4y by 3y',
                                                'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': 'male transfers compl in 4y by 4y',
                                                'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': 'male transfers compl in 4y by 6y',
                                                'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': 'male transfers compl in 4y by 8y',
                                                
                                                'latest.completion.title_iv.female.completed_by.2yrs': 'females compl t9 by 2y',
                                                'latest.completion.title_iv.female.completed_by.3yrs': 'females compl t9 by 3y',
                                                'latest.completion.title_iv.female.completed_by.4yrs': 'females compl t9 by 4y',
                                                'latest.completion.title_iv.female.completed_by.6yrs': 'females compl t9 by 6y',
                                                'latest.completion.title_iv.female.completed_by.8yrs': 'females compl t9 by 8y',
                                                'latest.completion.title_iv.female.withdrawn_by.2yrs': 'females withdr t9 by 2y',
                                                'latest.completion.title_iv.female.withdrawn_by.3yrs': 'females withdr t9 by 3y',
                                                'latest.completion.title_iv.female.withdrawn_by.4yrs': 'females withdr t9 by 4y',
                                                'latest.completion.title_iv.female.withdrawn_by.6yrs': 'females withdr t9 by 6y',
                                                'latest.completion.title_iv.female.withdrawn_by.8yrs': 'females withdr t9 by 8y',
                                                'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': 'female transfers withdr t9 in 4y by 2y',
                                                'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 'female transfers withdr t9 in 4y by 3y',
                                                'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': 'female transfers withdr t9 in 4y by 4y',
                                                'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 'female transfers withdr t9 in 4y by 6y',
                                                'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 'female transfers withdr t9 in 4y by 8y',
                                                'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': 'female transfers compl t9 in 4y by 2y',
                                                'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': 'female transfers compl t9 in 4y by 3y',
                                                'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': 'female transfers compl t9 in 4y by 4y',
                                                'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': 'female transfers compl t9 in 4y by 6y',
                                                'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': 'female transfers compl t9 in 4y by 8y'
                                             
                                             })

# student_sex_df = student_sex_df.fillna(0)
pd.set_option('display.max_columns', None)

# %%
student_sex_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
student_sex_df = student_sex_df.drop_duplicates(subset='school name')
student_sex_df = student_sex_df.set_index('school name')
student_sex_df = student_sex_df.fillna(0)
student_sex_df
# Out:
#                                                     women only schools  \
# school name
# Alabama A & M University                                           0.0
# University of Alabama at Birmingham                                0.0
# Amridge University                                                 0.0
# University of Alabama in Huntsville                                0.0
# Alabama State University                                           0.0
# ...                                                                ...
# Universal Technical Institute-West Texas                           0.0
# Avalon Institute-Las Vegas                                         0.0
# Medspa Academies-National Institute of Modern A...                 0.0
# American Institute-Cherry Hill                                     0.0
# Glendale Career College-North-West College-Bake...                 0.0
#
#                                                     men only schools  \
# school name
# ...

# %%
#convert to cleaned csv and json
student_sex_df.to_csv('CSVs/student_sex.csv')
student_sex_df.to_json('JSONs/student_sex.json', orient = 'index', compression = 'infer', index = 'true')

# %%
student_gen_df = student_gen_df.drop(columns = ['latest.student.demographics.share_bachelors_degree_age25.home_ZIP',
                                                'latest.student.demographics.share_born_US.home_ZIP', 
                                                'latest.student.demographics.share_white.home_ZIP',
                                                'latest.student.demographics.share_hispanic.home_ZIP', 
                                                'latest.student.demographics.share_black.home_ZIP',
                                                'latest.student.demographics.share_asian.home_ZIP',
                                                'latest.student.demographics.share_professional_degree_age25.home_ZIP',
                                                'latest.completion.title_iv.not_first_gen.died_by.2yrs',
                                                'latest.completion.title_iv.mid_inc.died_by.2yrs',
                                                'latest.completion.title_iv.low_inc.died_by.2yrs',
                                                'latest.completion.title_iv.independ.died_by.2yrs'])
student_gen_df = student_gen_df.rename(columns={'latest.school.name': 'school name',
                                                'location.lat': 'latitude',
                                                'location.lon': 'longitude',
                                                'latest.student.share_independent_lowincome.0_30000': 'indep low income students (0-30000)',
                                                'latest.student.share_independent_students': 'indep students',
                                                'latest.student.share_dependent_lowincome.0_300000': 'dep low income students (0-30000)',
                                                'latest.student.share_lowincome.0_30000': 'low income students',
                                                'latest.student.share_firstgeneration': 'student share for 1-gen',
                                                'latest.student.share_firstgeneration_parents.somecollege': '1-gen with parents went to college',
                                                'latest.student.share_firstgeneration_parents.middleschool': '1-gen with parents went to middleschool',
                                                'latest.student.share_firstgeneration_parents.highschool': '1-gen with parents went to highschool',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': 't9 1-gen transfers in 4y compl by 2y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': 't9 1-gen transfers in 4y compl by 3y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs': 't9 1-gen transfers in 4y compl by 4y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': 't9 1-gen transfers in 4y compl by 6y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': 't9 1-gen transfers in 4y compl by 8y',
                                                'latest.completion.title_iv.independ.completed_by.2yrs': 't9 indep students compl by 2y',
                                                'latest.completion.title_iv.independ.completed_by.3yrs': 't9 indep students compl by 3y',
                                                'latest.completion.title_iv.independ.completed_by.4yrs': 't9 indep students compl by 4y',
                                                'latest.completion.title_iv.independ.completed_by.6yrs': 't9 indep students compl by 6y',
                                                'latest.completion.title_iv.independ.completed_by.8yrs': 't9 indep students compl by 8y',
                                                'latest.completion.title_iv.independ.withdrawn_by.2yrs': 't9 indep students withdr by 2y',
                                                'latest.completion.title_iv.independ.withdrawn_by.3yrs': 't9 indep students withdr by 3y',
                                                'latest.completion.title_iv.independ.withdrawn_by.4yrs': 't9 indep students withdr by 4y',
                                                'latest.completion.title_iv.independ.withdrawn_by.6yrs': 't9 indep students withdr by 6y',
                                                'latest.completion.title_iv.independ.withdrawn_by.8yrs': 't9 indep students withdr by 8y',
                                                'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.2yrs': 't9 indep transfers withdr by 2y',
                                                'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.3yrs': 't9 indep transfers withdr by 3y',
                                                'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.4yrs': 't9 indep transfers withdr by 4y',
                                                'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.6yrs': 't9 indep transfers withdr by 6y',
                                                'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.8yrs': 't9 indep transfers withdr by 8y',
                                                'latest.completion.title_iv.independ.transf_completed_4yr_by.2yrs': 't9 indep transfers compl by 2y',
                                                'latest.completion.title_iv.independ.transf_completed_4yr_by.3yrs': 't9 indep transfers compl by 3y',
                                                'latest.completion.title_iv.independ.transf_completed_4yr_by.4yrs': 't9 indep transfers compl by 4y',
                                                'latest.completion.title_iv.independ.transf_completed_4yr_by.6yrs': 't9 indep transfers compl by 6y',
                                                'latest.completion.title_iv.independ.transf_completed_4yr_by.8yrs': 't9 indep transfers compl by 8y',
                                                'latest.completion.title_iv.depend.completed_by.2yrs': 't9 dep students compl by 2y',
                                                'latest.completion.title_iv.depend.completed_by.3yrs': 't9 dep students compl by 3y',
                                                'latest.completion.title_iv.depend.completed_by.4yrs': 't9 dep students compl by 4y',
                                                'latest.completion.title_iv.depend.completed_by.6yrs': 't9 dep students compl by 6y',
                                                'latest.completion.title_iv.depend.completed_by.8yrs': 't9 dep students compl by 8y',
                                                'latest.completion.title_iv.depend.withdrawn_by.2yrs': 't9 dep students withdr by 2y',
                                                'latest.completion.title_iv.depend.withdrawn_by.3yrs': 't9 dep students withdr by 3y',
                                                'latest.completion.title_iv.depend.withdrawn_by.4yrs': 't9 dep students withdr by 4y',
                                                'latest.completion.title_iv.depend.withdrawn_by.6yrs': 't9 dep students withdr by 6y',
                                                'latest.completion.title_iv.depend.withdrawn_by.8yrs': 't9 dep students withdr by 8y',
                                                'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.2yrs': 't9 dep transfers in 4y withdr by 2y',
                                                'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.3yrs': 't9 dep transfers in 4y withdr by 3y',
                                                'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.4yrs': 't9 dep transfers in 4y withdr by 4y',
                                                'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.6yrs': 't9 dep transfers in 4y withdr by 6y',
                                                'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.8yrs': 't9 dep transfers in 4y withdr by 8y',
                                                'latest.completion.title_iv.depend.transf_completed_4yr_by.2yrs': 't9 dep transfers in 4y compl by 2y',
                                                'latest.completion.title_iv.depend.transf_completed_4yr_by.3yrs': 't9 dep transfers in 4y compl by 3y',
                                                'latest.completion.title_iv.depend.transf_completed_4yr_by.4yrs': 't9 dep transfers in 4y compl by 4y',
                                                'latest.completion.title_iv.depend.transf_completed_4yr_by.6yrs': 't9 dep transfers in 4y compl by 6y',
                                                'latest.completion.title_iv.depend.transf_completed_4yr_by.8yrs': 't9 dep transfers in 4y compl by 8y',
                                                'latest.completion.title_iv.not_first_gen.completed_by.2yrs': 't9 non-1-gen compl by 2y',
                                                'latest.completion.title_iv.not_first_gen.completed_by.3yrs': 't9 non-1-gen compl by 3y',
                                                'latest.completion.title_iv.not_first_gen.completed_by.4yrs': 't9 non-1-gen compl by 4y',
                                                'latest.completion.title_iv.not_first_gen.completed_by.6yrs': 't9 non-1-gen compl by 6y',
                                                'latest.completion.title_iv.not_first_gen.completed_by.8yrs': 't9 non-1-gen compl by 8y',
                                                'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs': 't9 non-1-gen withdr by 2y',
                                                'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs': 't9 non-1-gen withdr by 3y',
                                                'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs': 't9 non-1-gen withdr by 4y',
                                                'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs': 't9 non-1-gen withdr by 6y',
                                                'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs': 't9 non-1-gen withdr by 8y',
                                                'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.2yrs': 't9 non-1-gen transfers in 4y withdr by 2y',
                                                'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.3yrs': 't9 non-1-gen transfers in 4y withdr by 3y',
                                                'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.4yrs': 't9 non-1-gen transfers in 4y withdr by 4y',
                                                'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.6yrs': 't9 non-1-gen transfers in 4y withdr by 6y',
                                                'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.8yrs': 't9 non-1-gen transfers in 4y withdr by 8y',
                                                'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.2yrs': 't9 non-1-gen transfers in 4y compl by 2y',
                                                'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.3yrs': 't9 non-1-gen transfers in 4y compl by 3y',
                                                'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.4yrs': 't9 non-1-gen transfers in 4y compl by 4y',
                                                'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.6yrs': 't9 non-1-gen transfers in 4y compl by 6y',
                                                'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.8yrs': 't9 non-1-gen transfers in 4y compl by 8y',
                                                'latest.completion.title_iv.first_gen.completed_by.2yrs': 't9 1-gen students completed by 2y',
                                                'latest.completion.title_iv.first_gen.completed_by.3yrs': 't9 1-gen students completed by 3y',
                                                'latest.completion.title_iv.first_gen.completed_by.4yrs': 't9 1-gen students completed by 4y',
                                                'latest.completion.title_iv.first_gen.completed_by.6yrs': 't9 1-gen students completed by 6y',
                                                'latest.completion.title_iv.first_gen.completed_by.8yrs': 't9 1-gen students completed by 8y',
                                                'latest.completion.title_iv.first_gen.withdrawn_by.2yrs': 't9 1-gen students withdr by 2y',
                                                'latest.completion.title_iv.first_gen.withdrawn_by.3yrs': 't9 1-gen students withdr by 3y',
                                                'latest.completion.title_iv.first_gen.withdrawn_by.4yrs': 't9 1-gen students withdr by 4y',
                                                'latest.completion.title_iv.first_gen.withdrawn_by.6yrs': 't9 1-gen students withdr by 6y',
                                                'latest.completion.title_iv.first_gen.withdrawn_by.8yrs': 't9 1-gen students withdr by 8y',
                                                'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.2yrs': 't9 1-gen transfers in 4y withdrawn by 2y',
                                                'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.3yrs': 't9 1-gen transfers in 4y withdrawn by 3y',
                                                'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.4yrs': 't9 1-gen transfers in 4y withdrawn by 4y',
                                                'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.6yrs': 't9 1-gen transfers in 4y withdrawn by 6y',
                                                'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.8yrs': 't9 1-gen transfers in 4y withdrawn by 8y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': 't9 1-gen transfers in 4y compl by 2y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': 't9 1-gen transfers in 4y compl by 3y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs': 't9 1-gen transfers in 4y compl by 4y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': 't9 1-gen transfers in 4y compl by 6y',
                                                'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': 't9 1-gen transfers in 4y compl by 8y'


                                               })
# student_gen_df = student_gen_df.fillna(0)
pd.set_option('display.max_columns', None)

# %%
student_gen_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
student_gen_df = student_gen_df.drop_duplicates(subset='school name')
student_gen_df = student_gen_df.set_index('school name')
student_gen_df = student_gen_df.fillna(0)
student_gen_df
# Out:
#                                                     indep low income students (0-30000)  \
# school name
# Alabama A & M University                                                       0.901587
# University of Alabama at Birmingham                                            0.594203
# Amridge University                                                             0.000000
# University of Alabama in Huntsville                                            0.688852
# Alabama State University                                                       0.921933
# ...                                                                                 ...
# Universal Technical Institute-West Texas                                       0.721907
# Avalon Institute-Las Vegas                                                     0.756955
# Medspa Academies-National Institute of Modern A...                             0.540541
# ...

# %%
#convert to cleaned csv and json
student_gen_df.to_csv('CSVs/student_gen.csv')
student_gen_df.to_json('JSONs/student_gen.json', orient = 'index', compression = 'infer', index = 'true')

# %%
retention_rate_df = retention_rate_df.drop(columns=['latest.student.enrollment.all',
                                                    'latest.school.state_fips',
                                                    'latest.academics.program_reporter.programs_offered',
                                                    'latest.school.degrees_awarded.highest',
                                                    'latest.admissions.sat_scores.midpoint.writing',
                                                    'latest.admissions.sat_scores.midpoint.math',
                                                    'latest.admissions.sat_scores.midpoint.critical_reading',
                                                    'latest.admissions.sat_scores.average.by_ope_id',
                                                    'latest.admissions.sat_scores.average.overall',
                                                    'latest.admissions.act_scores.midpoint.writing',
                                                    'latest.admissions.act_scores.midpoint.math',
                                                    'latest.admissions.act_scores.midpoint.english',
                                                    'latest.completion.completion_rate_less_than_4yr_150nt',
                                                    'latest.cost.roomboard.oncampus',
                                                    'latest.cost.otherexpense.oncampus',
                                                    'latest.cost.roomboard.offcampus',
                                                    'latest.cost.otherexpense.offcampus',
                                                    'latest.cost.booksupply'
                                                   ])

retention_rate_df = retention_rate_df.rename(columns={'latest.school.name': 'school name',
                                                      'location.lat': 'latitude',
                                                      'location.lon': 'longitude',
                                                      'latest.cost.title_iv.public.all': 't9 cost for public schools',
                                                      'latest.aid.federal_loan_rate': 'federal loan rate',
                                                      'latest.cost.title_iv.private.all': 't9 cost for private schools',
                                                      'latest.school.tuition_revenue_per_fte': 'tuition revenue per full time enrollment',
                                                      'latest.cost.tuition.in_state': 'tuition cost for in state students',
                                                      'latest.completion.completion_rate_l4yr_150_nhpi': 'compl rate for under 4y (hawaiian/pac islander)',
                                                      'latest.completion.completion_rate_l4yr_150_black': 'compl rate for under 4y (black)',
                                                      'latest.completion.completion_rate_l4yr_150_asian': 'compl rate for under 4y (asian)',
                                                      'latest.completion.completion_rate_l4yr_150_aian': 'compl rate for under 4y (american indian)',
                                                      'latest.completion.completion_rate_l4yr_150_white': 'compl rate for under 4y (white)', 
                                                      'latest.completion.completion_rate_l4yr_150_hispanic': 'compl rate for under 4y (hispanic)',
                                                      'latest.completion.completion_rate_4yr_150_white': 'compl rate for 4y (white)',
                                                      'latest.completion.completion_rate_l4yr_150_2ormore': 'compl rate for under 4y (2 or more races)',
                                                      'latest.completion.completion_rate_4yr_150_2ormore': 'compl rate for 4y (2 or more races)',
                                                      'latest.completion.completion_rate_4yr_150_nhpi': 'compl rate for 4y (hawaiian/pac islander)',
                                                      'latest.completion.completion_rate_4yr_150_hispanic': 'compl rate for 4y (hispanic)',
                                                      'latest.completion.completion_rate_4yr_150_black': 'compl rate for 4y (black)',
                                                      'latest.completion.completion_rate_4yr_150_asian': 'compl rate for 4y (asian)',
                                                      'latest.completion.completion_rate_4yr_150_aian': 'compl rate for 4y (american indian)',
                                                      'latest.completion.completion_rate_4yr_150nt_pooled': '1st_time fulltime compl 4y (2y avg)',
                                                      'latest.completion.completion_rate_4yr_150nt': '1st_time fulltime compl 4y',
                                                      'latest.student.retention_rate.four_year.part_time_pooled': 'part time student retention rate for 4y',
                                                      'latest.student.retention_rate.lt_four_year.full_time_pooled': 'full time students under 4y',
                                                      'latest.student.retention_rate.four_year.full_time_pooled': 'full time students in 4y',
                                                      'latest.cost.otherexpense.withfamily': 'cost of attendance w fam other expenses'})
# retention_rate_df = retention_rate_df.fillna(0)
pd.set_option('display.max_columns', None)

# %%
retention_rate_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
retention_rate_df = retention_rate_df.drop_duplicates(subset='school name')
retention_rate_df = retention_rate_df.set_index('school name')
retention_rate_df = retention_rate_df.fillna(0)
retention_rate_df
# Out:
#                                                     federal loan rate  \
# school name
# Alabama A & M University                                       0.6552
# University of Alabama at Birmingham                            0.4401
# Amridge University                                             0.8423
# University of Alabama in Huntsville                            0.3578
# Alabama State University                                       0.7637
# ...                                                               ...
# Universal Technical Institute-West Texas                       0.0000
# Avalon Institute-Las Vegas                                     0.0000
# Medspa Academies-National Institute of Modern A...             0.6071
# American Institute-Cherry Hill                                 0.9412
# Glendale Career College-North-West College-Bake...             0.0000
#
#                                                     t9 cost for public schools  \
# school name
# ...

# %%
#convert to cleaned csv and json
retention_rate_df.to_csv('CSVs/retention_rate.csv')
retention_rate_df.to_json('JSONs/retention_rate.json', orient = 'index', compression = 'infer', index = 'true')

# %%
attendance_cost_df = attendance_cost_df.drop(columns=['latest.cost.net_price.program_reporter.by_income_level.75001-110000',
                                                      'latest.cost.net_price.private.by_income_level.75001-110000',
                                                      'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000',
                                                      'latest.cost.net_price.program_reporter.by_income_level.75000-plus',
                                                      'latest.cost.net_price.private.by_income_level.75000-plus',
                                                      'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus',
                                                      'latest.cost.net_price.program_reporter.by_income_level.48001-75000',
                                                      'latest.cost.net_price.private.by_income_level.48001-75000',
                                                      'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000',
                                                      'latest.cost.net_price.program_reporter.by_income_level.30001-75000',
                                                      'latest.cost.net_price.private.by_income_level.30001-75000',
                                                      'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000',
                                                      'latest.cost.net_price.program_reporter.by_income_level.30001-48000',
                                                      'latest.cost.net_price.private.by_income_level.30001-48000',
                                                      'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000',
                                                      'latest.cost.net_price.program_reporter.by_income_level.110001-plus'])
                                                      

attendance_cost_df = attendance_cost_df.rename(columns={'latest.school.name': 'school name',
                                                        'location.lat': 'latitude',
                                                        'location.lon': 'longitude',
                                                        'latest.school.city': 'school city',
                                                        'latest.school.carnegie_undergrad': 'carnegie undergrad profile',
                                                        'latest.school.carnegie_size_setting': 'carnegie size setting',
                                                        'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': 'avg months to complete program 1',
                                                        'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': 'avg months to complete program 2',
                                                        'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': 'avg months to complete program 3',
                                                        'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': 'avg months to complete program 4',
                                                        'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': 'avg months to complete program 5',
                                                        'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': 'avg months to complete program 6',
                                                        'latest.cost.net_price.private.by_income_level.110001-plus': '110k+ fam income avg cost(private)',
                                                        'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus':'110k+ fam income avg cost(other)',
                                                        'latest.cost.net_price.public.by_income_level.0-48000': '0-48k fam income avg cost(public)',
                                                        'latest.cost.net_price.private.by_income_level.0-48000': '0-48k fam income avg cost(private)',
                                                        'latest.cost.net_price.program_reporter.by_income_level.0-48000': '0-48k fam income avg cost(program-year)',
                                                        'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': '0-48k fam income avg cost(other)',
                                                        'latest.cost.net_price.public.by_income_level.0-30000': '0-30k fam income avg cost(public)',
                                                        'latest.cost.net_price.program_reporter.by_income_level.0-30000': '0-30k fam income avg cost(program-year)',
                                                        'latest.cost.net_price.private.by_income_level.0-30000': '0-30k fam income avg cost(private)',
                                                        'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': '0-30k fam income avg cost(other)',
                                                        'latest.cost.avg_net_price.public': 'avg price (public)',
                                                        'latest.cost.avg_net_price.private': 'avg price (private)',
                                                        'latest.cost.avg_net_price.other_academic_year': 'avg price (other academic year)',
                                                        'latest.cost.avg_net_price.program_year': 'avg price (program year)',
                                                        'latest.cost.net_price.public.by_income_level.75001-110000': 'public $ by income (75001-110k)',
                                                        'latest.cost.net_price.public.by_income_level.75000-plus': 'public $ by income (75000 plus)',
                                                        'latest.cost.net_price.public.by_income_level.48001-75000': 'public $ by income (48001-75k)',
                                                        'latest.cost.net_price.public.by_income_level.30001-75000': 'public $ by income (30001-75k)',
                                                        'latest.cost.net_price.public.by_income_level.30001-48000': 'public $ by income (30001-48k)',
                                                        'latest.cost.net_price.public.by_income_level.110001-plus': 'public $ by income (110001-plus)',
                                                        'latest.admissions.admission_rate.overall': 'overall admission rate'
                                                        
                                                        
                                                   })
# attendance_cost_df = attendance_cost_df.fillna(0)
pd.set_option('display.max_columns', None)

# %%
attendance_cost_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)

# %%
attendance_cost_df = attendance_cost_df.drop_duplicates(subset='school name')
attendance_cost_df = attendance_cost_df.set_index('school name')
attendance_cost_df = attendance_cost_df.fillna(0)
attendance_cost_df
# Out:
#                                                     school city  \
# school name
# Alabama A & M University                                 Normal
# University of Alabama at Birmingham                  Birmingham
# Amridge University                                   Montgomery
# University of Alabama in Huntsville                  Huntsville
# Alabama State University                             Montgomery
# ...                                                         ...
# Universal Technical Institute-West Texas                 Austin
# Avalon Institute-Las Vegas                            Las Vegas
# Medspa Academies-National Institute of Modern A...    Las Vegas
# American Institute-Cherry Hill                      Cherry Hill
# Glendale Career College-North-West College-Bake...  Bakersfield
#
#                                                     carnegie undergrad profile  \
# school name
# Alabama A & M University                                                  10.0
# ...

# %%
#convert to cleaned csv and json
attendance_cost_df.to_csv('CSVs/attendance_cost.csv')
attendance_cost_df.to_json('JSONs/attendance_cost.json', orient = 'index', compression = 'infer', index = 'true')

# %%
school_roots_df = school_roots_df.rename(columns={'latest.school.name': 'school name',
                                                  'location.lat': 'latitude',
                                                  'location.lon': 'longitude'
                                                 })
pd.set_option('display.max_columns', None)

# %%
school_roots_df.dropna(subset=['school name', 'id', 'latitude', 'longitude'], inplace = True)
school_roots_df
# Out:
#                                             school name      id   latitude  \
# 0                              Alabama A & M University  100654  34.783368
# 1                   University of Alabama at Birmingham  100663  33.505697
# 2                                    Amridge University  100690  32.362609
# 3                   University of Alabama in Huntsville  100706  34.724557
# 4                              Alabama State University  100724  32.364317
# ...                                                 ...     ...        ...
# 6041           Universal Technical Institute-West Texas  497286  30.415828
# 6042                         Avalon Institute-Las Vegas  497301  36.142355
# 6043  Medspa Academies-National Institute of Modern ...  497310  36.117236
# 6044                     American Institute-Cherry Hill  497329  39.939428
# 6045  Glendale Career College-North-West College-Bak...  497338  35.339951
#
#        longitude
# 0     -86.568502
# 1     -86.799345
# ...

# %%
school_roots_df = school_roots_df.drop_duplicates(subset='school name')
school_roots_df = school_roots_df.set_index('school name')
school_roots_df
# Out:
#                                                         id   latitude  \
# school name
# Alabama A & M University                            100654  34.783368
# University of Alabama at Birmingham                 100663  33.505697
# Amridge University                                  100690  32.362609
# University of Alabama in Huntsville                 100706  34.724557
# Alabama State University                            100724  32.364317
# ...                                                    ...        ...
# Universal Technical Institute-West Texas            497286  30.415828
# Avalon Institute-Las Vegas                          497301  36.142355
# Medspa Academies-National Institute of Modern A...  497310  36.117236
# American Institute-Cherry Hill                      497329  39.939428
# Glendale Career College-North-West College-Bake...  497338  35.339951
#
#                                                      longitude
# school name
# ...

# %%
#convert to cleaned csv and json
school_roots_df.to_csv('CSVs/school_roots.csv')
school_roots_df.to_json('JSONs/school_roots.json', orient = 'index', compression = 'infer', index = 'true')
