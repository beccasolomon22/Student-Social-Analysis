# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# %%
#import all DataFrames
attendance_cost = pd.read_csv('CSVs/attendance_cost.csv', index_col=0)
retention = pd.read_csv('CSVs/retention_rate.csv', index_col=0)
student_demo = pd.read_csv('CSVs/student_demo.csv', index_col=0)
student_gen = pd.read_csv('CSVs/student_gen.csv', index_col=0)
student_income = pd.read_csv('CSVs/student_income.csv', index_col=0)
student_sex = pd.read_csv('CSVs/student_sex.csv', index_col=0)

# %%
attendance_cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   school city                              5938 non-null   object
#  1   carnegie undergrad profile               5938 non-null   float64
#  2   carnegie size setting                    5938 non-null   float64
#  3   avg months to complete program 1         5938 non-null   float64
#  4   avg months to complete program 2         5938 non-null   float64
#  5   avg months to complete program 3         5938 non-null   float64
#  6   avg months to complete program 4         5938 non-null   float64
#  7   avg months to complete program 5         5938 non-null   float64
#  8   avg months to complete program 6         5938 non-null   float64
# ...

# %%
retention.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 28 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   federal loan rate                                5938 non-null   float64
#  1   t9 cost for public schools                       5938 non-null   float64
#  2   t9 cost for private schools                      5938 non-null   float64
#  3   tuition revenue per full time enrollment         5938 non-null   float64
#  4   tuition cost for in state students               5938 non-null   float64
#  5   part time student retention rate for 4y          5938 non-null   float64
#  6   full time students under 4y                      5938 non-null   float64
#  7   full time students in 4y                         5938 non-null   float64
# ...

# %%
student_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 39 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   zipcode                                                    5938 non-null   object
#  1   student size                                               5938 non-null   float64
#  2   pell grant rate                                            5938 non-null   float64
#  3   average faculty salary                                     5938 non-null   float64
#  4   fulltime faculty rate                                      5938 non-null   float64
#  5   admission test requirements                                5938 non-null   float64
#  6   completion rate in 4 years (hawaiian or pacific islander)  5938 non-null   float64
# ...

# %%
#student_gen_2 = student_gen.drop(columns=['id','latitude','longitude'])
student_gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 91 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   indep low income students (0-30000)        5938 non-null   float64
#  1   indep students                             5938 non-null   float64
#  2   dep low income students (0-30000)          5938 non-null   float64
#  3   low income students                        5938 non-null   float64
#  4   student share for 1-gen                    5938 non-null   float64
#  5   1-gen with parents went to college         5938 non-null   float64
#  6   1-gen with parents went to middleschool    5938 non-null   float64
#  7   1-gen with parents went to highschool      5938 non-null   float64
#  8   t9 1-gen transfers in 4y compl by 2y       5938 non-null   float64
# ...

# %%
student_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 63 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   student median family income            5938 non-null   float64
#  1   t9 low inc comp by 3y                   5938 non-null   float64
#  2   t9 low inc comp by 4y                   5938 non-null   float64
#  3   t9 low inc comp by 6y                   5938 non-null   float64
#  4   t9 low inc comp by 8y                   5938 non-null   float64
#  5   t9 low inc withdr by 2y                 5938 non-null   float64
#  6   t9 low inc withdr by 3y                 5938 non-null   float64
#  7   t9 low inc withdr by 4y                 5938 non-null   float64
#  8   t9 low inc withdr by 6y                 5938 non-null   float64
# ...

# %%
student_sex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5938 entries, Alabama A & M University to Glendale Career College-North-West College-Bakersfield
# Data columns (total 45 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   women only schools                      5938 non-null   float64
#  1   men only schools                        5938 non-null   float64
#  2   males compl t9 by 2y                    5938 non-null   float64
#  3   males compl t9 by 3y                    5938 non-null   float64
#  4   males compl t9 by 4y                    5938 non-null   float64
#  5   males compl t9 by 6y                    5938 non-null   float64
#  6   males compl t9 by 8y                    5938 non-null   float64
#  7   males withdr t9 by 2y                   5938 non-null   float64
#  8   males withdr t9 by 3y                   5938 non-null   float64
# ...

# %%
retention_short_5 = retention[['federal loan rate', 't9 cost for public schools', 'id', 'latitude', 'longitude']]
retention_short_5
# Out:
#                                                     federal loan rate  \
# school name
# Alabama A & M University                                       0.6552
# University of Alabama at Birmingham                            0.4401
# Amridge University                                             0.8423
# University of Alabama in Huntsville                            0.3578
# Alabama State University                                       0.7637
# ...                                                               ...
# Universal Technical Institute-West Texas                       0.0000
# Avalon Institute-Las Vegas                                     0.0000
# Medspa Academies-National Institute of Modern A...             0.6071
# American Institute-Cherry Hill                                 0.9412
# Glendale Career College-North-West College-Bake...             0.0000
#
#                                                     t9 cost for public schools  \
# school name
# ...

# %%
retention_short_5.to_csv('retention_short_5.csv')
