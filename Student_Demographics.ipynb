# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# Import API key
from doe_api import doe_key

# %%
#demographics

url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    "latest.school.zip,latest.student.size,latest.root.id,latest.school.region_id,"+
    "latest.aid.pell_grant_rate,latest.school.faculty_salary,latest.school.ft_faculty_rate,"+
    
    #admissions test requirements
    "latest.admissions.test_requirements,"+
    
    #completion rate demographics
    "latest.completion.completion_rate_4yr_150_nhpi,"+ 
    "latest.completion.completion_rate_4yr_150_aian,latest.completion.completion_rate_4yr_150_asian,"+
    "latest.completion.completion_rate_4yr_150_hispanic,latest.completion.completion_rate_4yr_150_black,"+
    "latest.completion.completion_rate_4yr_150_white,"+
    
    
    #student demographics
    "latest.student.demographics.race_ethnicity.white,latest.student.demographics.race_ethnicity.hispanic,"+
    "latest.student.demographics.race_ethnicity.black,latest.student.demographics.race_ethnicity.api,"+
    "latest.student.demographics.race_ethnicity.aian,latest.student.demographics.women,latest.student.demographics.men,"+
    
    #median debt per demographic
    "latest.aid.median_debt.income.30001_75000,latest.aid.median_debt.income.0_30000,latest.aid.median_debt.income.greater_than_75000,"+
    "latest.aid.median_debt.noncompleters,latest.aid.median_debt.completers.overall,latest.aid.median_debt.male_students,"+
    "latest.aid.median_debt.independent_students,latest.aid.median_debt.female_students,latest.aid.median_debt.dependent_students,"+
    
    
    #faculty demographics
    "latest.student.demographics.faculty.women,latest.student.demographics.faculty.race_ethnicity.white,"+
    "latest.student.demographics.faculty.race_ethnicity.non_resident_alien,latest.student.demographics.faculty.race_ethnicity.two_or_more,"+
    "latest.student.demographics.faculty.race_ethnicity.unknown,latest.student.demographics.faculty.race_ethnicity.nhpi,"+
    "latest.student.demographics.faculty.men,latest.student.demographics.faculty.race_ethnicity.hispanic,"+
    "latest.student.demographics.faculty.race_ethnicity.black,latest.student.demographics.faculty.race_ethnicity.asian,"+
    "latest.student.demographics.faculty.race_ethnicity.aian,"+
    
    #religious affiliation
    "latest.school.religious_affiliation,"+
    
    #undergrads age 25 and above
    "latest.student.share_25_older"
    
    
    
}

response = requests.get(url, params=params)
response = response.json()
pprint(response)
# Out:
# {'metadata': {'page': 0, 'per_page': 100, 'total': 6543},
#  'results': [{'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 31000,
#               'latest.aid.median_debt.dependent_students': 16057,
#               'latest.aid.median_debt.female_students': 18216,
#               'latest.aid.median_debt.income.0_30000': 17500,
#               'latest.aid.median_debt.income.30001_75000': 16000,
#               'latest.aid.median_debt.income.greater_than_75000': 15000,
#               'latest.aid.median_debt.independent_students': 20000,
#               'latest.aid.median_debt.male_students': 15000,
#               'latest.aid.median_debt.noncompleters': 10500,
#               'latest.aid.pell_grant_rate': 0.6853,
#               'latest.completion.completion_rate_4yr_150_aian': 0,
#               'latest.completion.completion_rate_4yr_150_asian': 0,
#               'latest.completion.completion_rate_4yr_150_black': 0.2805,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.2222,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_4yr_150_white': 0.3043,
#               'latest.school.faculty_salary': 8779,
#               'latest.school.ft_faculty_rate': 0.6833,
#               'latest.school.name': 'Alabama A & M University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35762',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0047,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0995,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.654,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0095,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0095,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.1469,
#               'latest.student.demographics.men': 0.406,
#               'latest.student.demographics.race_ethnicity.aian': 0.0027,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.8978,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0114,
#               'latest.student.demographics.race_ethnicity.white': 0.0184,
#               'latest.student.demographics.women': 0.594,
#               'latest.student.share_25_older': 0.0617,
#               'latest.student.size': 5098},
#              {'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 22300,
#               'latest.aid.median_debt.dependent_students': 15250,
#               'latest.aid.median_debt.female_students': 16183,
#               'latest.aid.median_debt.income.0_30000': 16666,
#               'latest.aid.median_debt.income.30001_75000': 15985,
#               'latest.aid.median_debt.income.greater_than_75000': 15000,
#               'latest.aid.median_debt.independent_students': 16944,
#               'latest.aid.median_debt.male_students': 15248,
#               'latest.aid.median_debt.noncompleters': 10204,
#               'latest.aid.pell_grant_rate': 0.3253,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8354,
#               'latest.completion.completion_rate_4yr_150_black': 0.5565,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.5769,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.6276,
#               'latest.school.faculty_salary': 11590,
#               'latest.school.ft_faculty_rate': 0.7564,
#               'latest.school.name': 'University of Alabama at Birmingham',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35294-0110',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0015,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.1575,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0619,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0319,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0.0012,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0081,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0004,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.6808,
#               'latest.student.demographics.men': 0.379,
#               'latest.student.demographics.race_ethnicity.aian': 0.0021,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.2458,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0669,
#               'latest.student.demographics.race_ethnicity.white': 0.5297,
#               'latest.student.demographics.women': 0.621,
#               'latest.student.share_25_older': 0.1794,
#               'latest.student.size': 13284},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 32189,
#               'latest.aid.median_debt.dependent_students': 9166,
#               'latest.aid.median_debt.female_students': 13385,
#               'latest.aid.median_debt.income.0_30000': 12875,
#               'latest.aid.median_debt.income.30001_75000': 18803,
#               'latest.aid.median_debt.income.greater_than_75000': 19917,
#               'latest.aid.median_debt.independent_students': 14250,
#               'latest.aid.median_debt.male_students': 12901,
#               'latest.aid.median_debt.noncompleters': 10500,
#               'latest.aid.pell_grant_rate': 0.7852,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': 0.2857,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 1,
#               'latest.school.faculty_salary': 4672,
#               'latest.school.ft_faculty_rate': 0.7872,
#               'latest.school.name': 'Amridge University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': 74,
#               'latest.school.zip': '36117-3553',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0294,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.9706,
#               'latest.student.demographics.men': 0.3147,
#               'latest.student.demographics.race_ethnicity.aian': 0,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.6932,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0438,
#               'latest.student.demographics.race_ethnicity.white': 0.247,
#               'latest.student.demographics.women': 0.6853,
#               'latest.student.share_25_older': 0.8606,
#               'latest.student.size': 251},
#              {'latest.admissions.test_requirements': 1,
#               'latest.aid.median_debt.completers.overall': 20705,
#               'latest.aid.median_debt.dependent_students': 13665,
#               'latest.aid.median_debt.female_students': 14000,
#               'latest.aid.median_debt.income.0_30000': 14502,
#               'latest.aid.median_debt.income.30001_75000': 13075,
#               'latest.aid.median_debt.income.greater_than_75000': 13954,
#               'latest.aid.median_debt.independent_students': 15245,
#               'latest.aid.median_debt.male_students': 13660,
#               'latest.aid.median_debt.noncompleters': 10185,
#               'latest.aid.pell_grant_rate': 0.2377,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6667,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8125,
#               'latest.completion.completion_rate_4yr_150_black': 0.4845,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.6444,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.6098,
#               'latest.school.faculty_salary': 9820,
#               'latest.school.ft_faculty_rate': 0.6538,
#               'latest.school.name': 'University of Alabama in Huntsville',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35899',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0085,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.1823,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0513,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0256,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0028,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.6809,
#               'latest.student.demographics.men': 0.5953,
#               'latest.student.demographics.race_ethnicity.aian': 0.008,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.0871,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.061,
#               'latest.student.demographics.race_ethnicity.white': 0.7196,
#               'latest.student.demographics.women': 0.4047,
#               'latest.student.share_25_older': 0.1519,
#               'latest.student.size': 7358},
#              {'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 31000,
#               'latest.aid.median_debt.dependent_students': 17000,
#               'latest.aid.median_debt.female_students': 18750,
#               'latest.aid.median_debt.income.0_30000': 17750,
#               'latest.aid.median_debt.income.30001_75000': 17000,
#               'latest.aid.median_debt.income.greater_than_75000': 18500,
#               'latest.aid.median_debt.independent_students': 21500,
#               'latest.aid.median_debt.male_students': 14573,
#               'latest.aid.median_debt.noncompleters': 11000,
#               'latest.aid.pell_grant_rate': 0.7205,
#               'latest.completion.completion_rate_4yr_150_aian': 0,
#               'latest.completion.completion_rate_4yr_150_asian': 0.3333,
#               'latest.completion.completion_rate_4yr_150_black': 0.2844,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.4286,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.3636,
#               'latest.school.faculty_salary': 7701,
#               'latest.school.ft_faculty_rate': 0.6812,
#               'latest.school.name': 'Alabama State University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36104-0271',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.1584,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.6063,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0136,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.009,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.2127,
#               'latest.student.demographics.men': 0.3505,
#               'latest.student.demographics.race_ethnicity.aian': 0.0017,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.9259,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0129,
#               'latest.student.demographics.race_ethnicity.white': 0.0152,
#               'latest.student.demographics.women': 0.6495,
#               'latest.student.share_25_older': 0.0677,
#               'latest.student.size': 3495},
#              {'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 22750,
#               'latest.aid.median_debt.dependent_students': 18283,
#               'latest.aid.median_debt.female_students': 18750,
#               'latest.aid.median_debt.income.0_30000': 17750,
#               'latest.aid.median_debt.income.30001_75000': 18500,
#               'latest.aid.median_debt.income.greater_than_75000': 17750,
#               'latest.aid.median_debt.independent_students': 16444,
#               'latest.aid.median_debt.male_students': 16500,
#               'latest.aid.median_debt.noncompleters': 10250,
#               'latest.aid.pell_grant_rate': 0.1712,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6207,
#               'latest.completion.completion_rate_4yr_150_asian': 0.7912,
#               'latest.completion.completion_rate_4yr_150_black': 0.5663,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.661,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0.625,
#               'latest.completion.completion_rate_4yr_150_white': 0.7468,
#               'latest.school.faculty_salary': 10509,
#               'latest.school.ft_faculty_rate': 0.7753,
#               'latest.school.name': 'The University of Alabama',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35487-0100',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0018,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.094,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0645,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0283,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0.0018,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0074,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0018,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.7462,
#               'latest.student.demographics.men': 0.4385,
#               'latest.student.demographics.race_ethnicity.aian': 0.0037,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.105,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0549,
#               'latest.student.demographics.race_ethnicity.white': 0.7676,
#               'latest.student.demographics.women': 0.5615,
#               'latest.student.share_25_older': 0.0735,
#               'latest.student.size': 30725},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 9766,
#               'latest.aid.median_debt.dependent_students': 4960,
#               'latest.aid.median_debt.female_students': 6000,
#               'latest.aid.median_debt.income.0_30000': 6500,
#               'latest.aid.median_debt.income.30001_75000': 5874,
#               'latest.aid.median_debt.income.greater_than_75000': 5000,
#               'latest.aid.median_debt.independent_students': 8450,
#               'latest.aid.median_debt.male_students': 4781,
#               'latest.aid.median_debt.noncompleters': 4514,
#               'latest.aid.pell_grant_rate': 0.2982,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 6523,
#               'latest.school.ft_faculty_rate': 0.3824,
#               'latest.school.name': 'Central Alabama Community College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35010',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.122,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0244,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.8537,
#               'latest.student.demographics.men': 0.3915,
#               'latest.student.demographics.race_ethnicity.aian': 0.0021,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1947,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0287,
#               'latest.student.demographics.race_ethnicity.white': 0.7245,
#               'latest.student.demographics.women': 0.6085,
#               'latest.student.share_25_older': 0.1565,
#               'latest.student.size': 940},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 18051,
#               'latest.aid.median_debt.dependent_students': 12000,
#               'latest.aid.median_debt.female_students': 15000,
#               'latest.aid.median_debt.income.0_30000': 15650,
#               'latest.aid.median_debt.income.30001_75000': 14848,
#               'latest.aid.median_debt.income.greater_than_75000': 13487,
#               'latest.aid.median_debt.independent_students': 17750,
#               'latest.aid.median_debt.male_students': 13461,
#               'latest.aid.median_debt.noncompleters': 11883,
#               'latest.aid.pell_grant_rate': 0.4036,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 8834,
#               'latest.school.ft_faculty_rate': 0.4554,
#               'latest.school.name': 'Athens State University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35611',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0247,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0864,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.1111,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0247,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.7531,
#               'latest.student.demographics.men': 0.2951,
#               'latest.student.demographics.race_ethnicity.aian': 0.0131,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1243,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0426,
#               'latest.student.demographics.race_ethnicity.white': 0.7634,
#               'latest.student.demographics.women': 0.7049,
#               'latest.student.share_25_older': 0.5569,
#               'latest.student.size': 2511},
#              {'latest.admissions.test_requirements': 1,
#               'latest.aid.median_debt.completers.overall': 25000,
#               'latest.aid.median_debt.dependent_students': 12000,
#               'latest.aid.median_debt.female_students': 13750,
#               'latest.aid.median_debt.income.0_30000': 13000,
#               'latest.aid.median_debt.income.30001_75000': 14125,
#               'latest.aid.median_debt.income.greater_than_75000': 12500,
#               'latest.aid.median_debt.independent_students': 16502,
#               'latest.aid.median_debt.male_students': 11585,
#               'latest.aid.median_debt.noncompleters': 8810,
#               'latest.aid.pell_grant_rate': 0.4821,
#               'latest.completion.completion_rate_4yr_150_aian': 0.4,
#               'latest.completion.completion_rate_4yr_150_asian': 0.2222,
#               'latest.completion.completion_rate_4yr_150_black': 0.3287,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.25,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_4yr_150_white': 0.3889,
#               'latest.school.faculty_salary': 7885,
#               'latest.school.ft_faculty_rate': 0.6901,
#               'latest.school.name': 'Auburn University at Montgomery',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36117-3596',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0045,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0987,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0717,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0179,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0628,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.6771,
#               'latest.student.demographics.men': 0.3314,
#               'latest.student.demographics.race_ethnicity.aian': 0.004,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.4487,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0131,
#               'latest.student.demographics.race_ethnicity.white': 0.4129,
#               'latest.student.demographics.women': 0.6686,
#               'latest.student.share_25_older': 0.2031,
#               'latest.student.size': 3742},
#              {'latest.admissions.test_requirements': 2,
#               'latest.aid.median_debt.completers.overall': 21000,
#               'latest.aid.median_debt.dependent_students': 17562,
#               'latest.aid.median_debt.female_students': 18500,
#               'latest.aid.median_debt.income.0_30000': 18750,
#               'latest.aid.median_debt.income.30001_75000': 18250,
#               'latest.aid.median_debt.income.greater_than_75000': 16750,
#               'latest.aid.median_debt.independent_students': 18489,
#               'latest.aid.median_debt.male_students': 16250,
#               'latest.aid.median_debt.noncompleters': 8750,
#               'latest.aid.pell_grant_rate': 0.1301,
#               'latest.completion.completion_rate_4yr_150_aian': 0.7917,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8321,
#               'latest.completion.completion_rate_4yr_150_black': 0.6898,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.7647,
#               'latest.completion.completion_rate_4yr_150_nhpi': 1,
#               'latest.completion.completion_rate_4yr_150_white': 0.8206,
#               'latest.school.faculty_salary': 11093,
#               'latest.school.ft_faculty_rate': 0.8436,
#               'latest.school.name': 'Auburn University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36849',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0041,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.1092,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0637,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0403,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0.0012,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0146,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0053,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.7179,
#               'latest.student.demographics.men': 0.5047,
#               'latest.student.demographics.race_ethnicity.aian': 0.0027,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.0461,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0382,
#               'latest.student.demographics.race_ethnicity.white': 0.8181,
#               'latest.student.demographics.women': 0.4953,
#               'latest.student.share_25_older': 0.04,
#               'latest.student.size': 24782},
#              {'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 25000,
#               'latest.aid.median_debt.dependent_students': None,
#               'latest.aid.median_debt.female_students': 17500,
#               'latest.aid.median_debt.income.0_30000': 12000,
#               'latest.aid.median_debt.income.30001_75000': 17730,
#               'latest.aid.median_debt.income.greater_than_75000': 16250,
#               'latest.aid.median_debt.independent_students': None,
#               'latest.aid.median_debt.male_students': 13849,
#               'latest.aid.median_debt.noncompleters': 8750,
#               'latest.aid.pell_grant_rate': 0.2152,
#               'latest.completion.completion_rate_4yr_150_aian': 0.5,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8,
#               'latest.completion.completion_rate_4yr_150_black': 0.5818,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.6,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.7147,
#               'latest.school.faculty_salary': 7636,
#               'latest.school.ft_faculty_rate': 0.8295,
#               'latest.school.name': 'Birmingham-Southern College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': 71,
#               'latest.school.zip': '35254',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0099,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0198,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0495,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0099,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0099,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.901,
#               'latest.student.demographics.men': 0.4895,
#               'latest.student.demographics.race_ethnicity.aian': 0.0038,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1603,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0573,
#               'latest.student.demographics.race_ethnicity.white': 0.729,
#               'latest.student.demographics.women': 0.5105,
#               'latest.student.share_25_older': 0.017,
#               'latest.student.size': 1048},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 10500,
#               'latest.aid.median_debt.dependent_students': 5469,
#               'latest.aid.median_debt.female_students': 6500,
#               'latest.aid.median_debt.income.0_30000': 6250,
#               'latest.aid.median_debt.income.30001_75000': 5500,
#               'latest.aid.median_debt.income.greater_than_75000': 5500,
#               'latest.aid.median_debt.independent_students': 9319,
#               'latest.aid.median_debt.male_students': 5500,
#               'latest.aid.median_debt.noncompleters': 5500,
#               'latest.aid.pell_grant_rate': 0.4568,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 6452,
#               'latest.school.ft_faculty_rate': 0.3053,
#               'latest.school.name': 'Chattahoochee Valley Community College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36869',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.025,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.2,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.775,
#               'latest.student.demographics.men': 0.3406,
#               'latest.student.demographics.race_ethnicity.aian': 0.0018,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.4833,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0641,
#               'latest.student.demographics.race_ethnicity.white': 0.3406,
#               'latest.student.demographics.women': 0.6594,
#               'latest.student.share_25_older': 0.3301,
#               'latest.student.size': 1107},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 26123,
#               'latest.aid.median_debt.dependent_students': 13668,
#               'latest.aid.median_debt.female_students': 13624,
#               'latest.aid.median_debt.income.0_30000': 12643,
#               'latest.aid.median_debt.income.30001_75000': 15278,
#               'latest.aid.median_debt.income.greater_than_75000': 14700,
#               'latest.aid.median_debt.independent_students': 12990,
#               'latest.aid.median_debt.male_students': 10834,
#               'latest.aid.median_debt.noncompleters': 9500,
#               'latest.aid.pell_grant_rate': 0.5536,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': 0.0588,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.2222,
#               'latest.school.faculty_salary': 5061,
#               'latest.school.ft_faculty_rate': 0.1731,
#               'latest.school.name': 'South University-Montgomery',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36116',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.4,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.6,
#               'latest.student.demographics.men': 0.1543,
#               'latest.student.demographics.race_ethnicity.aian': 0,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.6884,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0237,
#               'latest.student.demographics.race_ethnicity.white': 0.2582,
#               'latest.student.demographics.women': 0.8457,
#               'latest.student.share_25_older': 0.6804,
#               'latest.student.size': 337},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 7499,
#               'latest.aid.median_debt.dependent_students': 5500,
#               'latest.aid.median_debt.female_students': 5408,
#               'latest.aid.median_debt.income.0_30000': 5362,
#               'latest.aid.median_debt.income.30001_75000': 5552,
#               'latest.aid.median_debt.income.greater_than_75000': 5500,
#               'latest.aid.median_debt.independent_students': 6537,
#               'latest.aid.median_debt.male_students': 6209,
#               'latest.aid.median_debt.noncompleters': 5500,
#               'latest.aid.pell_grant_rate': 0.3709,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 8764,
#               'latest.school.ft_faculty_rate': 0.4672,
#               'latest.school.name': 'Enterprise State Community College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36330-1300',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0351,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.1053,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0175,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0175,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.8246,
#               'latest.student.demographics.men': 0.5277,
#               'latest.student.demographics.race_ethnicity.aian': 0.0075,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1991,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0584,
#               'latest.student.demographics.race_ethnicity.white': 0.6198,
#               'latest.student.demographics.women': 0.4723,
#               'latest.student.share_25_older': 0.2244,
#               'latest.student.size': 1336},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 11000,
#               'latest.aid.median_debt.dependent_students': 5500,
#               'latest.aid.median_debt.female_students': 6500,
#               'latest.aid.median_debt.income.0_30000': 5746,
#               'latest.aid.median_debt.income.30001_75000': 6261,
#               'latest.aid.median_debt.income.greater_than_75000': 5500,
#               'latest.aid.median_debt.independent_students': 9500,
#               'latest.aid.median_debt.male_students': 5500,
#               'latest.aid.median_debt.noncompleters': 5500,
#               'latest.aid.pell_grant_rate': 0.3142,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 7345,
#               'latest.school.ft_faculty_rate': 0.3761,
#               'latest.school.name': 'Coastal Alabama Community College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '36507-2698',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0179,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.006,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.1012,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0119,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0119,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.006,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.8452,
#               'latest.student.demographics.men': 0.3592,
#               'latest.student.demographics.race_ethnicity.aian': 0.0155,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.2375,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0339,
#               'latest.student.demographics.race_ethnicity.white': 0.6396,
#               'latest.student.demographics.women': 0.6408,
#               'latest.student.share_25_older': 0.2206,
#               'latest.student.size': 5217},
#              {'latest.admissions.test_requirements': 5,
#               'latest.aid.median_debt.completers.overall': 23000,
#               'latest.aid.median_debt.dependent_students': 11500,
#               'latest.aid.median_debt.female_students': 16665,
#               'latest.aid.median_debt.income.0_30000': 15750,
#               'latest.aid.median_debt.income.30001_75000': 14000,
#               'latest.aid.median_debt.income.greater_than_75000': 14600,
#               'latest.aid.median_debt.independent_students': 16603,
#               'latest.aid.median_debt.male_students': 11792,
#               'latest.aid.median_debt.noncompleters': 8250,
#               'latest.aid.pell_grant_rate': 0.461,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': 0.25,
#               'latest.completion.completion_rate_4yr_150_black': 0.1293,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0.3333,
#               'latest.completion.completion_rate_4yr_150_white': 0.2101,
#               'latest.school.faculty_salary': 6271,
#               'latest.school.ft_faculty_rate': 0.5511,
#               'latest.school.name': 'Faulkner University',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': 74,
#               'latest.school.zip': '36109-3390',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0078,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.031,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0465,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0078,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0078,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.8992,
#               'latest.student.demographics.men': 0.4287,
#               'latest.student.demographics.race_ethnicity.aian': 0.0018,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.4133,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0318,
#               'latest.student.demographics.race_ethnicity.white': 0.4599,
#               'latest.student.demographics.women': 0.5713,
#               'latest.student.share_25_older': 0.4313,
#               'latest.student.size': 1696},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': None,
#               'latest.aid.median_debt.dependent_students': None,
#               'latest.aid.median_debt.female_students': None,
#               'latest.aid.median_debt.income.0_30000': None,
#               'latest.aid.median_debt.income.30001_75000': None,
#               'latest.aid.median_debt.income.greater_than_75000': None,
#               'latest.aid.median_debt.independent_students': None,
#               'latest.aid.median_debt.male_students': None,
#               'latest.aid.median_debt.noncompleters': None,
#               'latest.aid.pell_grant_rate': 0.4522,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 6832,
#               'latest.school.ft_faculty_rate': 0.4941,
#               'latest.school.name': 'Gadsden State Community College',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35903',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.008,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.032,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.024,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.024,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.912,
#               'latest.student.demographics.men': 0.3746,
#               'latest.student.demographics.race_ethnicity.aian': 0.0026,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.2024,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0603,
#               'latest.student.demographics.race_ethnicity.white': 0.6812,
#               'latest.student.demographics.women': 0.6254,
#               'latest.student.share_25_older': 0.3261,
#               'latest.student.size': 3513},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 9500,
#               'latest.aid.median_debt.dependent_students': 4920,
#               'latest.aid.median_debt.female_students': None,
#               'latest.aid.median_debt.income.0_30000': 5500,
#               'latest.aid.median_debt.income.30001_75000': None,
#               'latest.aid.median_debt.income.greater_than_75000': None,
#               'latest.aid.median_debt.independent_students': 7253,
#               'latest.aid.median_debt.male_students': None,
#               'latest.aid.median_debt.noncompleters': 3904,
#               'latest.aid.pell_grant_rate': 0.6538,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': None,
#               'latest.school.ft_faculty_rate': None,
#               'latest.school.name': 'New Beginning College of Cosmetology',
#               'latest.school.region_id': 5,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '35951',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.25,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.75,
#               'latest.student.demographics.men': 0.0351,
#               'latest.student.demographics.race_ethnicity.aian': 0,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
# ...
#              {'latest.admissions.test_requirements': 3,
#               'latest.aid.median_debt.completers.overall': 16300,
#               'latest.aid.median_debt.dependent_students': 11100,
#               'latest.aid.median_debt.female_students': 12500,
#               'latest.aid.median_debt.income.0_30000': 12500,
#               'latest.aid.median_debt.income.30001_75000': 12793,
#               'latest.aid.median_debt.income.greater_than_75000': 10500,
#               'latest.aid.median_debt.independent_students': 13834,
#               'latest.aid.median_debt.male_students': 12980,
#               'latest.aid.median_debt.noncompleters': 11000,
#               'latest.aid.pell_grant_rate': 0.4455,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': 0.5,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.5,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.3913,
#               'latest.school.faculty_salary': 5070,
#               'latest.school.ft_faculty_rate': 0.359,
#               'latest.school.name': 'Prescott College',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '86301',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0408,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0408,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0408,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.102,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0816,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.6939,
#               'latest.student.demographics.men': 0.3446,
#               'latest.student.demographics.race_ethnicity.aian': 0.0235,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.0287,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.0444,
#               'latest.student.demographics.race_ethnicity.white': 0.6789,
#               'latest.student.demographics.women': 0.6554,
#               'latest.student.share_25_older': 0.3196,
#               'latest.student.size': 383},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 8233,
#               'latest.aid.median_debt.dependent_students': 6122,
#               'latest.aid.median_debt.female_students': 7917,
#               'latest.aid.median_debt.income.0_30000': 7917,
#               'latest.aid.median_debt.income.30001_75000': 7917,
#               'latest.aid.median_debt.income.greater_than_75000': 7072,
#               'latest.aid.median_debt.independent_students': 8233,
#               'latest.aid.median_debt.male_students': 7917,
#               'latest.aid.median_debt.noncompleters': 4750,
#               'latest.aid.pell_grant_rate': 0.604,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 4379,
#               'latest.school.ft_faculty_rate': 0.9,
#               'latest.school.name': 'Refrigeration School Inc',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '85034-1816',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.1111,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.1111,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.2222,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.5556,
#               'latest.student.demographics.men': 0.9275,
#               'latest.student.demographics.race_ethnicity.aian': 0.1559,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1053,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.3297,
#               'latest.student.demographics.race_ethnicity.white': 0.3456,
#               'latest.student.demographics.women': 0.0725,
#               'latest.student.share_25_older': 0.5819,
#               'latest.student.size': 1007},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 9500,
#               'latest.aid.median_debt.dependent_students': 3201,
#               'latest.aid.median_debt.female_students': 4363,
#               'latest.aid.median_debt.income.0_30000': 4500,
#               'latest.aid.median_debt.income.30001_75000': 4500,
#               'latest.aid.median_debt.income.greater_than_75000': 3500,
#               'latest.aid.median_debt.independent_students': 4500,
#               'latest.aid.median_debt.male_students': 4347,
#               'latest.aid.median_debt.noncompleters': 3722,
#               'latest.aid.pell_grant_rate': 0.0936,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 6744,
#               'latest.school.ft_faculty_rate': 1,
#               'latest.school.name': 'Rio Salado College',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '85281',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0192,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0192,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0769,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0962,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0192,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.7692,
#               'latest.student.demographics.men': 0.3575,
#               'latest.student.demographics.race_ethnicity.aian': 0.0199,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1015,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.3154,
#               'latest.student.demographics.race_ethnicity.white': 0.4603,
#               'latest.student.demographics.women': 0.6425,
#               'latest.student.share_25_older': 0.3107,
#               'latest.student.size': 3824},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': None,
#               'latest.aid.median_debt.dependent_students': None,
#               'latest.aid.median_debt.female_students': None,
#               'latest.aid.median_debt.income.0_30000': None,
#               'latest.aid.median_debt.income.30001_75000': None,
#               'latest.aid.median_debt.income.greater_than_75000': None,
#               'latest.aid.median_debt.independent_students': None,
#               'latest.aid.median_debt.male_students': None,
#               'latest.aid.median_debt.noncompleters': None,
#               'latest.aid.pell_grant_rate': 0.4,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': None,
#               'latest.school.ft_faculty_rate': None,
#               'latest.school.name': 'Roberto-Venn School of Luthiery',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '85007',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0,
#               'latest.student.demographics.faculty.race_ethnicity.white': 1,
#               'latest.student.demographics.men': 1,
#               'latest.student.demographics.race_ethnicity.aian': 0,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0,
#               'latest.student.demographics.race_ethnicity.hispanic': 0,
#               'latest.student.demographics.race_ethnicity.white': 0.9167,
#               'latest.student.demographics.women': 0,
#               'latest.student.share_25_older': 0.5833,
#               'latest.student.size': 12},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 8000,
#               'latest.aid.median_debt.dependent_students': 3500,
#               'latest.aid.median_debt.female_students': 4500,
#               'latest.aid.median_debt.income.0_30000': 5243,
#               'latest.aid.median_debt.income.30001_75000': 4222,
#               'latest.aid.median_debt.income.greater_than_75000': 3500,
#               'latest.aid.median_debt.independent_students': 5250,
#               'latest.aid.median_debt.male_students': 4500,
#               'latest.aid.median_debt.noncompleters': 4100,
#               'latest.aid.pell_grant_rate': 0.1468,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 9887,
#               'latest.school.ft_faculty_rate': 1,
#               'latest.school.name': 'Scottsdale Community College',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '85256',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0079,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0315,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.0315,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.0551,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0079,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0157,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.8504,
#               'latest.student.demographics.men': 0.4265,
#               'latest.student.demographics.race_ethnicity.aian': 0.0432,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.051,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.2655,
#               'latest.student.demographics.race_ethnicity.white': 0.5267,
#               'latest.student.demographics.women': 0.5735,
#               'latest.student.share_25_older': 0.3284,
#               'latest.student.size': 4764},
#              {'latest.admissions.test_requirements': None,
#               'latest.aid.median_debt.completers.overall': 8000,
#               'latest.aid.median_debt.dependent_students': 3500,
#               'latest.aid.median_debt.female_students': 4500,
#               'latest.aid.median_debt.income.0_30000': 4847,
#               'latest.aid.median_debt.income.30001_75000': 4500,
#               'latest.aid.median_debt.income.greater_than_75000': 3839,
#               'latest.aid.median_debt.independent_students': 5000,
#               'latest.aid.median_debt.male_students': 4375,
#               'latest.aid.median_debt.noncompleters': 4500,
#               'latest.aid.pell_grant_rate': 0.3346,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.school.faculty_salary': 9586,
#               'latest.school.ft_faculty_rate': 1,
#               'latest.school.name': 'South Mountain Community College',
#               'latest.school.region_id': 6,
#               'latest.school.religious_affiliation': None,
#               'latest.school.zip': '85042',
#               'latest.student.demographics.faculty.race_ethnicity.aian': 0.0345,
#               'latest.student.demographics.faculty.race_ethnicity.asian': 0.0862,
#               'latest.student.demographics.faculty.race_ethnicity.black': 0.1034,
#               'latest.student.demographics.faculty.race_ethnicity.hispanic': 0.2069,
#               'latest.student.demographics.faculty.race_ethnicity.nhpi': 0,
#               'latest.student.demographics.faculty.race_ethnicity.two_or_more': 0.0172,
#               'latest.student.demographics.faculty.race_ethnicity.unknown': 0.0172,
#               'latest.student.demographics.faculty.race_ethnicity.white': 0.5345,
#               'latest.student.demographics.men': 0.4071,
#               'latest.student.demographics.race_ethnicity.aian': 0.0355,
#               'latest.student.demographics.race_ethnicity.api_2000': None,
#               'latest.student.demographics.race_ethnicity.black': 0.1457,
#               'latest.student.demographics.race_ethnicity.hispanic': 0.5754,
#               'latest.student.demographics.race_ethnicity.white': 0.1495,
#               'latest.student.demographics.women': 0.5929,
#               'latest.student.share_25_older': 0.2744,
#               'latest.student.size': 2395}]}

# %%
#By Income

url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    #median income
    "latest.student.demographics.median_family_income,latest.student.demographics.median_hh_income"
    
    #low income
    #general completion
    "latest.completion.title_iv.low_inc.completed_by.2yrs,latest.completion.title_iv.low_inc.completed_by.3yrs,"+
    "latest.completion.title_iv.low_inc.completed_by.4yrs,latest.completion.title_iv.low_inc.completed_by.6yrs,"+
    "latest.completion.title_iv.low_inc.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.low_inc.withdrawn_by.2yrs,latest.completion.title_iv.low_inc.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.low_inc.withdrawn_by.4yrs,latest.completion.title_iv.low_inc.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.low_inc.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.low_inc.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.low_inc.transf_completed_4yr_by.2yrs,latest.completion.title_iv.low_inc.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.low_inc.transf_completed_4yr_by.4yrs,latest.completion.title_iv.low_inc.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.low_inc.transf_completed_4yr_by.8yrs,"+
    
    #middle income
    #general completion
    "latest.completion.title_iv.mid_inc.completed_by.2yrs,latest.completion.title_iv.mid_inc.completed_by.3yrs,"+
    "latest.completion.title_iv.mid_inc.completed_by.4yrs,latest.completion.title_iv.mid_inc.completed_by.6yrs,"+
    "latest.completion.title_iv.mid_inc.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv

#               'latest.completion.title_iv.mid_inc.withdrawn_by.4yrs': 0.434210526316,
#               'latest.completion.title_iv.mid_inc.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.mid_inc.withdrawn_by.8yrs': None,
#               'latest.school.name': 'South Mountain Community College',
#               'latest.student.demographics.median_family_income': 21078}]}

# %%
#male/female
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    #men/women only
    "latest.school.women_only,latest.school.men_only,"+
    
    #male 
    #general completion
    "latest.completion.title_iv.male.completed_by.2yrs,latest.completion.title_iv.male.completed_by.3yrs,"+
    "latest.completion.title_iv.male.completed_by.4yrs,latest.completion.title_iv.male.completed_by.6yrs,"+
    "latest.completion.title_iv.male.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.male.withdrawn_by.2yrs,latest.completion.title_iv.male.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.male.withdrawn_by.4yrs,latest.completion.title_iv.male.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.male.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.male.transf_completed_4yr_by.2yrs,latest.completion.title_iv.male.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.male.transf_completed_4yr_by.4yrs,latest.completion.title_iv.male.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.male.transf_completed_4yr_by.8yrs,"+
    
    #female 
    #general completion
    "latest.completion.title_iv.female.completed_by.2yrs,latest.completion.title_iv.female.completed_by.3yrs,"+
    "latest.completion.title_iv.female.completed_by.4yrs,latest.completion.title_iv.female.completed_by.6yrs,"+
    "latest.completion.title_iv.female.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.female.withdrawn_by.2yrs,latest.completion.title_iv.female.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.female.withdrawn_by.4yrs,latest.completion.title_iv.female.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.female.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.female.transf_completed_4yr_by.2yrs,latest.completion.title_iv.female.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.female.transf_completed_4yr_by.4yrs,latest.completion.title_iv.female.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.female.transf_completed_4yr_by.8yrs"
    
}

response = requests.get(url, params=params)
response = response.json()
pprint(response)
# Out:
# {'metadata': {'page': 0, 'per_page': 100, 'total': 6543},
#  'results': [{'latest.completion.title_iv.female.completed_by.2yrs': 0.047149122807,
#               'latest.completion.title_iv.female.completed_by.3yrs': 0.178238341969,
#               'latest.completion.title_iv.female.completed_by.4yrs': 0.259389671362,
#               'latest.completion.title_iv.female.completed_by.6yrs': 0.357480314961,
#               'latest.completion.title_iv.female.completed_by.8yrs': 0.318014705882,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': 0.023834196891,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': 0.030516431925,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': 0.072440944882,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': 0.108455882353,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': 0.043859649123,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 0.060103626943,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': 0.066901408451,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 0.089763779528,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 0.119485294118,
#               'latest.completion.title_iv.female.withdrawn_by.2yrs': 0.297149122807,
#               'latest.completion.title_iv.female.withdrawn_by.3yrs': 0.251813471503,
#               'latest.completion.title_iv.female.withdrawn_by.4yrs': 0.287558685446,
#               'latest.completion.title_iv.female.withdrawn_by.6yrs': 0.233070866142,
#               'latest.completion.title_iv.female.withdrawn_by.8yrs': 0.196691176471,
#               'latest.completion.title_iv.male.completed_by.2yrs': 0.040662650602,
#               'latest.completion.title_iv.male.completed_by.3yrs': 0.081267217631,
#               'latest.completion.title_iv.male.completed_by.4yrs': 0.17638483965,
#               'latest.completion.title_iv.male.completed_by.6yrs': 0.244556113903,
#               'latest.completion.title_iv.male.completed_by.8yrs': 0.255681818182,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': 0.028925619835,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': 0.026239067055,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': 0.030150753769,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': 0.07196969697,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': 0.043674698795,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': 0.053719008264,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': 0.067055393586,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': 0.085427135678,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': 0.087121212121,
#               'latest.completion.title_iv.male.withdrawn_by.2yrs': 0.373493975904,
#               'latest.completion.title_iv.male.withdrawn_by.3yrs': 0.353994490358,
#               'latest.completion.title_iv.male.withdrawn_by.4yrs': 0.424198250729,
#               'latest.completion.title_iv.male.withdrawn_by.6yrs': 0.418760469012,
#               'latest.completion.title_iv.male.withdrawn_by.8yrs': 0.354166666667,
#               'latest.school.men_only': 0,
#               'latest.school.name': 'Alabama A & M University',
#               'latest.school.women_only': 0},
#              {'latest.completion.title_iv.female.completed_by.2yrs': 0.158123791103,
#               'latest.completion.title_iv.female.completed_by.3yrs': 0.351944167498,
#               'latest.completion.title_iv.female.completed_by.4yrs': 0.471216617211,
#               'latest.completion.title_iv.female.completed_by.6yrs': 0.558139534884,
#               'latest.completion.title_iv.female.completed_by.8yrs': 0.569100391134,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': 0.036266924565,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': 0.042372881356,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': 0.080118694362,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': 0.091137649277,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': 0.107561929596,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 0.021435692921,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': 0.026112759644,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 0.042111879321,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 0.035853976532,
#               'latest.completion.title_iv.female.withdrawn_by.2yrs': 0.189071566731,
#               'latest.completion.title_iv.female.withdrawn_by.3yrs': 0.192921236291,
#               'latest.completion.title_iv.female.withdrawn_by.4yrs': 0.186350148368,
#               'latest.completion.title_iv.female.withdrawn_by.6yrs': 0.150848522942,
#               'latest.completion.title_iv.female.withdrawn_by.8yrs': 0.123207301173,
#               'latest.completion.title_iv.male.completed_by.2yrs': 0.136759581882,
#               'latest.completion.title_iv.male.completed_by.3yrs': 0.28867761452,
#               'latest.completion.title_iv.male.completed_by.4yrs': 0.425298804781,
#               'latest.completion.title_iv.male.completed_by.6yrs': 0.509947643979,
#               'latest.completion.title_iv.male.completed_by.8yrs': 0.50358974359,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': 0.024390243902,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': 0.040622299049,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': 0.057768924303,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': 0.09109947644,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': 0.089230769231,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': 0.027657735523,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': 0.024900398406,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': 0.032460732984,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': 0.051282051282,
#               'latest.completion.title_iv.male.withdrawn_by.2yrs': 0.223867595819,
#               'latest.completion.title_iv.male.withdrawn_by.3yrs': 0.263612791703,
#               'latest.completion.title_iv.male.withdrawn_by.4yrs': 0.248007968127,
#               'latest.completion.title_iv.male.withdrawn_by.6yrs': 0.212565445026,
#               'latest.completion.title_iv.male.withdrawn_by.8yrs': 0.219487179487,
#               'latest.school.men_only': 0,
#               'latest.school.name': 'University of Alabama at Birmingham',
#               'latest.school.women_only': 0},
#              {'latest.completion.title_iv.female.completed_by.2yrs': None,
#               'latest.completion.title_iv.female.completed_by.3yrs': None,
#               'latest.completion.title_iv.female.completed_by.4yrs': None,
#               'latest.completion.title_iv.female.completed_by.6yrs': None,
#               'latest.completion.title_iv.female.completed_by.8yrs': 0.12389380531,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 0.151515151515,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 0.137614678899,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 0.265486725664,
#               'latest.completion.title_iv.female.withdrawn_by.2yrs': 0.508064516129,
#               'latest.completion.title_iv.female.withdrawn_by.3yrs': 0.525252525253,
#               'latest.completion.title_iv.female.withdrawn_by.4yrs': 0.518987341772,
#               'latest.completion.title_iv.female.withdrawn_by.6yrs': 0.495412844037,
#               'latest.completion.title_iv.female.withdrawn_by.8yrs': 0.283185840708,
#               'latest.completion.title_iv.male.completed_by.2yrs': None,
#               'latest.completion.title_iv.male.completed_by.3yrs': None,
#               'latest.completion.title_iv.male.completed_by.4yrs': None,
#               'latest.completion.title_iv.male.completed_by.6yrs': None,
#               'latest.completion.title_iv.male.completed_by.8yrs': 0
rs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': None,
#               'latest.completion.title_iv.male.withdrawn_by.2yrs': None,
#               'latest.completion.title_iv.male.withdrawn_by.3yrs': None,
#               'latest.completion.title_iv.male.withdrawn_by.4yrs': None,
#               'latest.completion.title_iv.male.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.male.withdrawn_by.8yrs': None,
#               'latest.school.men_only': 0,
#               'latest.school.name': 'Roberto-Venn School of Luthiery',
#               'latest.school.women_only': 0},
#              {'latest.completion.title_iv.female.completed_by.2yrs': 0.121167883212,
#               'latest.completion.title_iv.female.completed_by.3yrs': 0.174041297935,
#               'latest.completion.title_iv.female.completed_by.4yrs': 0.180555555556,
#               'latest.completion.title_iv.female.completed_by.6yrs': 0.135016465423,
#               'latest.completion.title_iv.female.completed_by.8yrs': 0.040643522439,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': 0.03503649635,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': 0.070796460177,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': 0.0875,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': 0.166849615807,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': 0.249788314987,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 0.047197640118,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': 0.034722222222,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 0.063666300768,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 0.077900084674,
#               'latest.completion.title_iv.female.withdrawn_by.2yrs': 0.337226277372,
#               'latest.completion.title_iv.female.withdrawn_by.3yrs': 0.299410029499,
#               'latest.completion.title_iv.female.withdrawn_by.4yrs': 0.277777777778,
#               'latest.completion.title_iv.female.withdrawn_by.6yrs': 0.257958287596,
#               'latest.completion.title_iv.female.withdrawn_by.8yrs': 0.202370872142,
#               'latest.completion.title_iv.male.completed_by.2yrs': 0.086466165414,
#               'latest.completion.title_iv.male.completed_by.3yrs': 0.115384615385,
#               'latest.completion.title_iv.male.completed_by.4yrs': 0.141494435612,
#               'latest.completion.title_iv.male.completed_by.6yrs': 0.10348977136,
#               'latest.completion.title_iv.male.completed_by.8yrs': 0.039963669391,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': 0.031954887218,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': 0.058528428094,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': 0.089030206677,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': 0.132370637786,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': 0.178928247048,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': 0.061872909699,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': 0.071542130366,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': 0.069795427196,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': 0.088101725704,
#               'latest.completion.title_iv.male.withdrawn_by.2yrs': 0.392857142857,
#               'latest.completion.title_iv.male.withdrawn_by.3yrs': 0.392976588629,
#               'latest.completion.title_iv.male.withdrawn_by.4yrs': 0.392686804452,
#               'latest.completion.title_iv.male.withdrawn_by.6yrs': 0.376654632972,
#               'latest.completion.title_iv.male.withdrawn_by.8yrs': 0.254314259764,
#               'latest.school.men_only': 0,
#               'latest.school.name': 'Scottsdale Community College',
#               'latest.school.women_only': 0},
#              {'latest.completion.title_iv.female.completed_by.2yrs': None,
#               'latest.completion.title_iv.female.completed_by.3yrs': None,
#               'latest.completion.title_iv.female.completed_by.4yrs': None,
#               'latest.completion.title_iv.female.completed_by.6yrs': 0.041095890411,
#               'latest.completion.title_iv.female.completed_by.8yrs': 0.026973026973,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.4yrs': 0.08125,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.6yrs': 0.093782929399,
#               'latest.completion.title_iv.female.transf_completed_4yr_by.8yrs': 0.12987012987,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.2yrs': 0.027272727273,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.3yrs': 0.054226475279,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.4yrs': 0.0546875,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.6yrs': 0.055848261328,
#               'latest.completion.title_iv.female.transf_withdrawn_4yr_by.8yrs': 0.076923076923,
#               'latest.completion.title_iv.female.withdrawn_by.2yrs': 0.457575757576,
#               'latest.completion.title_iv.female.withdrawn_by.3yrs': 0.432216905901,
#               'latest.completion.title_iv.female.withdrawn_by.4yrs': 0.4140625,
#               'latest.completion.title_iv.female.withdrawn_by.6yrs': 0.390937829294,
#               'latest.completion.title_iv.female.withdrawn_by.8yrs': 0.258741258741,
#               'latest.completion.title_iv.male.completed_by.2yrs': None,
#               'latest.completion.title_iv.male.completed_by.3yrs': None,
#               'latest.completion.title_iv.male.completed_by.4yrs': None,
#               'latest.completion.title_iv.male.completed_by.6yrs': 0.033762057878,
#               'latest.completion.title_iv.male.completed_by.8yrs': 0.019607843137,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.4yrs': 0.050574712644,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.6yrs': 0.073954983923,
#               'latest.completion.title_iv.male.transf_completed_4yr_by.8yrs': 0.119155354449,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.2yrs': 0.024844720497,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.3yrs': 0.05,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.4yrs': 0.057471264368,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.6yrs': 0.067524115756,
#               'latest.completion.title_iv.male.transf_withdrawn_4yr_by.8yrs': 0.070889894419,
#               'latest.completion.title_iv.male.withdrawn_by.2yrs': 0.610766045549,
#               'latest.completion.title_iv.male.withdrawn_by.3yrs': 0.606818181818,
#               'latest.completion.title_iv.male.withdrawn_by.4yrs': 0.51724137931,
#               'latest.completion.title_iv.male.withdrawn_by.6yrs': 0.519292604502,
#               'latest.completion.title_iv.male.withdrawn_by.8yrs': 0.32730015083,
#               'latest.school.men_only': 0,
#               'latest.school.name': 'South Mountain Community College',
#               'latest.school.women_only': 0}]}

# %%
#dependent/independent
#first gen/non-first gen
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    #students financially independent/dependent
    "latest.student.share_independent_lowincome.0_30000,latest.student.share_independent_students,latest.student.share_dependent_lowincome.0_300000,"+
    "latest.student.share_lowincome.0_30000,"+
    
    #first gen
    "latest.student.share_firstgeneration,latest.student.share_firstgeneration_parents.somecollege,"+
    "latest.student.share_firstgeneration_parents.middleschool,latest.student.share_firstgeneration_parents.highschool,"+
    
    #first gen tranfered to 4 year
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs,"+
    
    #via census data demographics (population of students by zipcode)
    "latest.student.demographics.share_bachelors_degree_age25.home_ZIP,latest.student.demographics.share_born_US.home_ZIP,"+
    "latest.student.demographics.share_white.home_ZIP,latest.student.demographics.share_hispanic.home_ZIP,"+
    "latest.student.demographics.share_black.home_ZIP,latest.student.demographics.share_asian.home_ZIP,"+
    "latest.student.demographics.share_professional_degree_age25.home_ZIP,"+
    
    #died
    "latest.completion.title_iv.not_first_gen.died_by.2yrs,latest.completion.title_iv.mid_inc.died_by.2yrs,"+
    "latest.completion.title_iv.low_inc.died_by.2yrs,latest.completion.title_iv.independ.died_by.2yrs,"+
    
    #independent
    #general completion
    "latest.completion.title_iv.independ.completed_by.2yrs,latest.completion.title_iv.independ.completed_by.3yrs,"+
    "latest.completion.title_iv.independ.completed_by.4yrs,latest.completion.title_iv.independ.completed_by.6yrs,"+
    "latest.completion.title_iv.independ.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.independ.withdrawn_by.2yrs,latest.completion.title_iv.independ.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.independ.withdrawn_by.4yrs,latest.completion.title_iv.independ.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.independ.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.independ.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.independ.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.independ.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.independ.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.independ.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.independ.transf_completed_4yr_by.2yrs,latest.completion.title_iv.independ.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.independ.transf_completed_4yr_by.4yrs,latest.completion.title_iv.independ.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.independ.transf_completed_4yr_by.8yrs,"+
    
    #dependent
    #general completion
    "latest.completion.title_iv.depend.completed_by.2yrs,latest.completion.title_iv.depend.completed_by.3yrs,"+
    "latest.completion.title_iv.depend.completed_by.4yrs,latest.completion.title_iv.depend.completed_by.6yrs,"+
    "latest.completion.title_iv.depend.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.depend.withdrawn_by.2yrs,latest.completion.title_iv.depend.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.depend.withdrawn_by.4yrs,latest.completion.title_iv.depend.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.depend.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.depend.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.depend.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.depend.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.depend.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.depend.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.depend.transf_completed_4yr_by.2yrs,latest.completion.title_iv.depend.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.depend.transf_completed_4yr_by.4yrs,latest.completion.title_iv.depend.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.depend.transf_completed_4yr_by.8yrs,"+
    
    #non-first gen
    #general completion
    "latest.completion.title_iv.not_first_gen.completed_by.2yrs,latest.completion.title_iv.not_first_gen.completed_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.completed_by.4yrs,latest.completion.title_iv.not_first_gen.completed_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs,latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs,latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.2yrs,latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.4yrs,latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.8yrs,"+
    
    #first gen
    #general completion
    "latest.completion.title_iv.first_gen.completed_by.2yrs,latest.completion.title_iv.first_gen.completed_by.3yrs,"+
    "latest.completion.title_iv.first_gen.completed_by.4yrs,latest.completion.title_iv.first_gen.completed_by.6yrs,"+
    "latest.completion.title_iv.first_gen.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.first_gen.withdrawn_by.2yrs,latest.completion.title_iv.first_gen.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.first_gen.withdrawn_by.4yrs,latest.completion.title_iv.first_gen.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.first_gen.withdrawn_by.8yrs,"+
    #transferred and withdrew
    "latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.2yrs,latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.3yrs,"+
    "latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.4yrs,latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.6yrs,"+
    "latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.8yrs,"+
    #transferred and completed
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs"
    
}

response = requests.get(url, params=params)
response = response.json()
pprint(response)
# Out:
# {'metadata': {'page': 0, 'per_page': 100, 'total': 6543},
#  'results': [{'latest

#               'latest.completion.title_iv.independ.transf_completed_4yr_by.8yrs': 0.103184713376,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.2yrs': 0.016789087093,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.3yrs': 0.022840119166,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.4yrs': 0.029279279279,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.6yrs': 0.033200531208,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.8yrs': 0.03949044586,
#               'latest.completion.title_iv.independ.withdrawn_by.2yrs': 0.223504721931,
#               'latest.completion.title_iv.independ.withdrawn_by.3yrs': 0.253227408143,
#               'latest.completion.title_iv.independ.withdrawn_by.4yrs': 0.225225225225,
#               'latest.completion.title_iv.independ.withdrawn_by.6yrs': 0.212483399734,
#               'latest.completion.title_iv.independ.withdrawn_by.8yrs': 0.185987261146,
#               'latest.completion.title_iv.low_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.mid_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.2yrs': 0.147872340426,
#               'latest.completion.title_iv.not_first_gen.completed_by.3yrs': 0.390557939914,
#               'latest.completion.title_iv.not_first_gen.completed_by.4yrs': 0.514634146341,
#               'latest.completion.title_iv.not_first_gen.completed_by.6yrs': 0.605633802817,
#               'latest.completion.title_iv.not_first_gen.completed_by.8yrs': 0.606936416185,
#               'latest.completion.title_iv.not_first_gen.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.2yrs': 0.03085106383,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.3yrs': 0.038626609442,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.4yrs': 0.081707317073,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.6yrs': 0.104225352113,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.8yrs': 0.10838150289,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.3yrs': 0.018240343348,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.4yrs': 0.023170731707,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.6yrs': 0.035211267606,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.8yrs': 0.030346820809,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs': 0.16914893617,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs': 0.168454935622,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs': 0.189024390244,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs': 0.142253521127,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs': 0.14450867052,
#               'latest.school.name': 'University of Alabama at Birmingham',
#               'latest.student.demographics.share_asian.home_ZIP': 1.10000002384185,
#               'latest.student.demographics.share_bachelors_degree_age25.home_ZIP': 15.9300003051757,
#               'latest.student.demographics.share_black.home_ZIP': 27.7600002288818,
#               'latest.student.demographics.share_born_US.home_ZIP': 96.5,
#               'latest.student.demographics.share_hispanic.home_ZIP': 2.02999997138977,
#               'latest.student.demographics.share_professional_degree_age25.home_ZIP': 8.55000019073486,
#               'latest.student.demographics.share_white.home_ZIP': 69.0199966430664,
#               'latest.student.share_dependent_lowincome.0_300000': 0.3487095003,
#               'latest.student.share_firstgeneration': 0.341223671,
#               'latest.student.share_firstgeneration_parents.highschool': 0.3189568706,
#               'latest.student.share_firstgeneration_parents.middleschool': 0.0222668004,
#               'latest.student.share_firstgeneration_parents.somecollege': 0.658776329,
#               'latest.student.share_independent_lowincome.0_30000': 0.5942028986,
#               'latest.student.share_independent_students': 0.3214086082,
#               'latest.student.share_lowincome.0_30000': 0.4276131917},
#              {'latest.completion.title_iv.depend.completed_by.2yrs': None,
#               'latest.completion.title_iv.depend.completed_by.3yrs': None,
#               'latest.completion.title_iv.depend.completed_by.4yrs': None,
#               'latest.completion.title_iv.depend.completed_by.6yrs': None,
#               'latest.completion.title_iv.depend.completed_by.8yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.6yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.8yrs': None,
#               'latest.completion.title_iv.depend.withdrawn_by.2yrs': None,
#               'latest.completion.title_iv.depend.withdrawn_by.3yrs': None,
#               'latest.completion.title_iv.depend.withdrawn_by.4yrs': None,
#               'latest.completion.title_iv.depend.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.depend.withdrawn_by.8yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.6yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.8yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.6yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.8yrs': None,
#               'latest.completion.title_iv.first_gen.withdrawn_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.withdrawn_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.withdrawn_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.first_gen.withdrawn_by.8yrs': None,
#               'latest.completion.title_iv.independ.completed_by.2yrs': None,
#               'latest.completion.title_iv.independ.completed_by.3yrs': None,
#               'latest.completion.title_iv.independ.completed_by.4yrs': None,
#               'latest.completion.title_iv.independ.completed_by.6yrs': None,
#               'latest.completion.title_iv.independ.completed_by.8yrs': None,
#               'latest.completion.title_iv.independ.died_by.2yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.6yrs': None,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.8yrs': None,
#               'latest.completion.title_iv.independ.withdrawn_by.2yrs': None,
#               'latest.completion.title_iv.independ.withdrawn_by.3yrs': None,
#               'latest.completion.title_iv.independ.withdrawn_by.4yrs': None,
#               'latest.completion.title_iv.independ.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.independ.withdrawn_by.8yrs': None,
#               'latest.completion.title_iv.low_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.mid_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.6yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.8yrs': None,
#               'latest.completion.title_iv.not_first_gen.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.6yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.8yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.6yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.8yrs': None,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs': None,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs': None,
#               'latest.school.name': 'Amridge University',
#               'latest.student.demographics.share_asian.home_ZIP': 1.28999996185302,
#               'latest.student.demographics.share_bachelors_degree_age25.home_ZIP': 13.2299995422363,
#               'latest.student.demographics.share_black.home_ZIP': 22.5300006866455,
#               'latest.student.demographics.share_born_US.home_ZIP': 94.0899963378906,
#               'latest.student.demographics.share_hispanic.home_ZIP': 6.94000005722046,
#               'latest.student.demographics.share_professional_degree_age25.home_ZIP': 7.01000022888183,
#               'latest.student.demographics.share_white.home_ZIP': 70.8799972534179,
#               'latest.student.share_dependent_lowincome.0_300000': None,
#               'latest.student.share_firstgeneration': 0.5125,
#               'latest.student.share_firstgeneration_parents.highschool': 0.4625,
#               'latest.student.share_firstgeneration_parents.middleschool': 0.05,
#               'latest.student.share_firstgeneration_parents.somecollege': 0.4875,
#               'latest.student.share_independent_lowincome.0_30000': None,
#               'latest.student.share_independent_students': 0.8952702703,
#               'latest.student.share_lowincome.0_30000': 0.7736486486},
#              {'latest.completion.title_iv.depend.completed_by.2yrs': 0.068965517241,
#               'latest.completion.title_iv.depend.completed_by.3yrs': 0.258426966292,
#               'latest.completion.title_iv.depend.completed_by.4yrs': 0.359408033827,
#               'latest.completion.title_iv.depend.completed_by.6yrs': 0.485714285714,
#               'latest.completion.title_iv.depend.completed_by.8yrs': 0.503293807642,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.3yrs': 0.0234082397,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.4yrs': 0.056025369979,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.6yrs': 0.098571428571,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.8yrs': 0.143610013175,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.3yrs': 0.019662921348,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.4yrs': 0.030655391121,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.6yrs': 0.037142857143,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.8yrs': 0.04347826087,
#               'latest.completion.title_iv.depend.withdrawn_by.2yrs': 0.198275862069,
#               'latest.completion.title_iv.depend.withdrawn_by.3yrs': 0.234082397004,
#               'latest.completion.title_iv.depend.withdrawn_by.4yrs': 0.283298097252,
#               'latest.completion.title_iv.depend.withdrawn_by.6yrs': 0.19,
#               'latest.completion.title_iv.depend.withdrawn_by.8yrs': 0.143610013175,
#               'latest.completion.title_iv.first_gen.completed_by.2yrs': 0.114788004137,
#               'latest.completion.title_iv.first_gen.completed_by.3yrs': 0.287268770403,
#               'latest.completion.title_iv.first_gen.completed_by.4yrs': 0.349642004773,
#               'latest.completion.title_iv.first_gen.completed_by.6yrs': 0.453947368421,
#               'latest.completion.title_iv.first_gen.completed_by.8yrs': 0.468671679198,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': 0.030467899891,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs': 0.071599045346,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': 0.110526315789,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': 0

#               'latest.student.share_firstgeneration_parents.somecollege': 0.5976650202,
#               'latest.student.share_independent_lowincome.0_30000': 0.7490007994,
#               'latest.student.share_independent_students': 0.488862837,
#               'latest.student.share_lowincome.0_30000': 0.6221180148},
#              {'latest.completion.title_iv.depend.completed_by.2yrs': None,
#               'latest.completion.title_iv.depend.completed_by.3yrs': None,
#               'latest.completion.title_iv.depend.completed_by.4yrs': None,
#               'latest.completion.title_iv.depend.completed_by.6yrs': 0.052325581395,
#               'latest.completion.title_iv.depend.completed_by.8yrs': 0.025641025641,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.4yrs': 0.065517241379,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.6yrs': 0.100290697674,
#               'latest.completion.title_iv.depend.transf_completed_4yr_by.8yrs': 0.137179487179,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.2yrs': 0.023943661972,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.3yrs': 0.057722308892,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.4yrs': 0.05,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.6yrs': 0.077034883721,
#               'latest.completion.title_iv.depend.transf_withdrawn_4yr_by.8yrs': 0.079487179487,
#               'latest.completion.title_iv.depend.withdrawn_by.2yrs': 0.549295774648,
#               'latest.completion.title_iv.depend.withdrawn_by.3yrs': 0.511700468019,
#               'latest.completion.title_iv.depend.withdrawn_by.4yrs': 0.465517241379,
#               'latest.completion.title_iv.depend.withdrawn_by.6yrs': 0.389534883721,
#               'latest.completion.title_iv.depend.withdrawn_by.8yrs': 0.252564102564,
#               'latest.completion.title_iv.first_gen.completed_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.6yrs': None,
#               'latest.completion.title_iv.first_gen.completed_by.8yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': 0.027689030884,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs': 0.061791967044,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': 0.084179970972,
#               'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': 0.118857901726,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.6yrs': 0.05732946299,
#               'latest.completion.title_iv.first_gen.transf_withdrawn_4yr_by.8yrs': 0.073041168659,
#               'latest.completion.title_iv.first_gen.withdrawn_by.2yrs': 0.534682080925,
#               'latest.completion.title_iv.first_gen.withdrawn_by.3yrs': 0.515441959531,
#               'latest.completion.title_iv.first_gen.withdrawn_by.4yrs': 0.468589083419,
#               'latest.completion.title_iv.first_gen.withdrawn_by.6yrs': 0.437590711176,
#               'latest.completion.title_iv.first_gen.withdrawn_by.8yrs': 0.28818061089,
#               'latest.completion.title_iv.independ.completed_by.2yrs': None,
#               'latest.completion.title_iv.independ.completed_by.3yrs': None,
#               'latest.completion.title_iv.independ.completed_by.4yrs': None,
#               'latest.completion.title_iv.independ.completed_by.6yrs': 0.02718006795,
#               'latest.completion.title_iv.independ.completed_by.8yrs': 0.022624434389,
#               'latest.completion.title_iv.independ.died_by.2yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.3yrs': None,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.4yrs': 0.072727272727,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.6yrs': 0.074745186863,
#               'latest.completion.title_iv.independ.transf_completed_4yr_by.8yrs': 0.115384615385,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.2yrs': 0.030023094688,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.3yrs': 0.044600938967,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.4yrs': 0.062626262626,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.6yrs': 0.047565118913,
#               'latest.completion.title_iv.independ.transf_withdrawn_4yr_by.8yrs': 0.070135746606,
#               'latest.completion.title_iv.independ.withdrawn_by.2yrs': 0.478060046189,
#               'latest.completion.title_iv.independ.withdrawn_by.3yrs': 0.492957746479,
#               'latest.completion.title_iv.independ.withdrawn_by.4yrs': 0.444444444444,
#               'latest.completion.title_iv.independ.withdrawn_by.6yrs': 0.482446206116,
#               'latest.completion.title_iv.independ.withdrawn_by.8yrs': 0.315610859729,
#               'latest.completion.title_iv.low_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.mid_inc.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.6yrs': None,
#               'latest.completion.title_iv.not_first_gen.completed_by.8yrs': None,
#               'latest.completion.title_iv.not_first_gen.died_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.3yrs': 0.0859375,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.4yrs': 0.134615384615,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.6yrs': 0.098445595855,
#               'latest.completion.title_iv.not_first_gen.transf_completed_4yr_by.8yrs': 0.189873417722,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.2yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.3yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.4yrs': None,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.6yrs': 0.082901554404,
#               'latest.completion.title_iv.not_first_gen.transf_withdrawn_4yr_by.8yrs': 0.088607594937,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs': 0.4,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs': 0.421875,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs': 0.336538461538,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs': 0.471502590674,
#               'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs': 0.26582278481,
#               'latest.school.name': 'South Mountain Community College',
#               'latest.student.demographics.share_asian.home_ZIP': 1.8400000333786,
#               'latest.student.demographics.share_bachelors_degree_age25.home_ZIP': 12.6300001144409,
#               'latest.student.demographics.share_black.home_ZIP': 8.36999988555908,
#               'latest.student.demographics.share_born_US.home_ZIP': 79.2200012207031,
#               'latest.student.demographics.share_hispanic.home_ZIP': 42.7999992370605,
#               'latest.student.demographics.share_professional_degree_age25.home_ZIP': 6.5,
#               'latest.student.demographics.share_white.home_ZIP': 60.3699989318847,
#               'latest.student.share_dependent_lowincome.0_300000': 0.5594347465,
#               'latest.student.share_firstgeneration': 0.5895117541,
#               'latest.student.share_firstgeneration_parents.highschool': 0.4189270645,
#               'latest.student.share_firstgeneration_parents.middleschool': 0.1705846896,
#               'latest.student.share_firstgeneration_parents.somecollege': 0.4104882459,
#               'latest.student.share_independent_lowincome.0_30000': 0.7688284519,
#               'latest.student.share_independent_students': 0.4427975915,
#               'latest.student.share_lowincome.0_30000': 0.6521537749}]}

# %%
#Academics
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    "latest.aid.federal_loan_rate,latest.cost.title_iv.public.all,latest.cost.title_iv.private.all,"+
    "latest.academics.program_reporter.programs_offered,latest.school.tuition_revenue_per_fte,"+
    
    #enrollment
    "latest.student.enrollment.all,"+
    
    #weird school specifics
    "latest.school.state_fips,latest.root.fed_sch_cd"+
    
    #tuition fees
    "latest.cost.tuition.out_of_state,latest.cost.tuition.in_state,"+
    
    #highest degree awarded
    "latest.school.degrees_awarded.highest,"+
    
    #test scores
    #sat
    "latest.admissions.sat_scores.midpoint.writing,latest.admissions.sat_scores.midpoint.math,"+
    "latest.admissions.sat_scores.midpoint.critical_reading,"+
    "latest.admissions.sat_scores.average.by_ope_id,latest.admissions.sat_scores.average.overall,"+
    #act
    "latest.admissions.act_scores.midpoint.writing,latest.admissions.act_scores.midpoint.math,"+
    "latest.admissions.act_scores.midpoint.english,latest.admissions.act_scores.midpoint.cumulative"
    
    #retention rate
    "latest.student.retention_rate.lt_four_year.part_time_pooled,latest.student.retention_rate.four_year.part_time_pooled,"+
    "latest.student.retention_rate.lt_four_year.full_time_pooled,latest.student.retention_rate.four_year.full_time_pooled,"+
    
    #cost
    "latest.cost.otherexpense.withfamily,latest.cost.roomboard.oncampus,latest.cost.otherexpense.oncampus,"+
    "latest.cost.roomboard.offcampus,latest.cost.otherexpense.offcampus,latest.cost.booksupply,"+
    
    #control of institution
    "latest.school.ownership"
    
    #less than 4 year first-time full-time
    "latest.completion.completion_rate_less_than_4yr_150nt_pooled,latest.completion.completion_rate_less_than_4yr_150nt,"+
    "latest.completion.completion_rate_l4yr_150_white,latest.completion.completion_rate_l4yr_150_2ormore,"+
    "latest.completion.completion_rate_l4yr_150_nhpi,latest.completion.completion_rate_l4yr_150_hispanic,"+
    "latest.completion.completion_rate_l4yr_150_black,latest.completion.completion_rate_l4yr_150_asian,"+
    "latest.completion.completion_rate_l4yr_150_aian,"+
    
    #4 year first-time full-time
    "latest.completion.completion_rate_4yr_150_white,latest.completion.completion_rate_4yr_150_2ormore,"+
    "latest.completion.completion_rate_4yr_150_nhpi,latest.completion.completion_rate_4yr_150_hispanic,"+
    "latest.completion.completion_rate_4yr_150_black,latest.completion.completion_rate_4yr_150_asian,"+
    "latest.completion.completion_rate_4yr_150_aian,latest.completion.completion_rate_4yr_150nt_pooled,"+
    "latest.completion.completion_rate_4yr_150nt"
    
}

response = requests.get(url, params=params)
response = response.json()
pprint(response)
# Out:
# {'metadata': {'page': 0, 'per_page': 100, 'total': 6543},
#  'results': [{'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 17,
#               'latest.admissions.act_scores.midpoint.math': 17,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 954,
#               'latest.admissions.sat_scores.average.overall': 954,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 475,
#               'latest.admissions.sat_scores.midpoint.math': 460,
#               'latest.admissions.sat_scores.midpoint.writing': 414,
#               'latest.aid.federal_loan_rate': 0.6552,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.3214,
#               'latest.completion.completion_rate_4yr_150_aian': 0,
#               'latest.completion.completion_rate_4yr_150_asian': 0,
#               'latest.completion.completion_rate_4yr_150_black': 0.2805,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.2222,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_4yr_150_white': 0.3043,
#               'latest.completion.completion_rate_4yr_150nt': 0.2807,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.2833,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1600,
#               'latest.cost.otherexpense.offcampus': 3090,
#               'latest.cost.otherexpense.oncampus': 3090,
#               'latest.cost.otherexpense.withfamily': 3440,
#               'latest.cost.roomboard.offcampus': 9520,
#               'latest.cost.roomboard.oncampus': 9520,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 657,
#               'latest.cost.tuition.in_state': 10024,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Alabama A & M University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 9243,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.559,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.56,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 28,
#               'latest.admissions.act_scores.midpoint.math': 25,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 1266,
#               'latest.admissions.sat_scores.average.overall': 1266,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 637,
#               'latest.admissions.sat_scores.midpoint.math': 644,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.4401,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.5,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8354,
#               'latest.completion.completion_rate_4yr_150_black': 0.5565,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.5769,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.6276,
#               'latest.completion.completion_rate_4yr_150nt': 0.6245,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.6181,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1200,
#               'latest.cost.otherexpense.offcampus': 5555,
#               'latest.cost.otherexpense.oncampus': 5555,
#               'latest.cost.otherexpense.withfamily': 5555,
#               'latest.cost.roomboard.offcampus': 12307,
#               'latest.cost.roomboard.oncampus': 12307,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 1053,
#               'latest.cost.tuition.in_state': 8568,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'University of Alabama at Birmingham',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 11678,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.8522,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.5426,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.8423,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': 0.2857,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 1,
#               'latest.completion.completion_rate_4yr_150nt': 0.4444,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.3846,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': None,
#               'latest.cost.otherexpense.offcampus': None,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': None,
#               'latest.cost.roomboard.offcampus': None,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': None,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Amridge University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 14093,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.5,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 28,
#               'latest.admissions.act_scores.midpoint.math': 26,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 1300,
#               'latest.admissions.sat_scores.average.overall': 1300,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 640,
#               'latest.admissions.sat_scores.midpoint.math': 655,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.3578,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.6,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6667,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8125,
#               'latest.completion.completion_rate_4yr_150_black': 0.4845,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.6444,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.6098,
#               'latest.completion.completion_rate_4yr_150nt': 0.6072,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.5925,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 2300,
#               'latest.cost.otherexpense.offcampus': 4156,
#               'latest.cost.otherexpense.oncampus': 4156,
#               'latest.cost.otherexpense.withfamily': 4156,
#               'latest.cost.roomboard.offcampus': 10764,
#               'latest.cost.roomboard.oncampus': 10764,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 515,
#               'latest.cost.tuition.in_state': 11488,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'University of Alabama in Huntsville',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 8246,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.8048,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.1628,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 17,
#               'latest.admissions.act_scores.midpoint.math': 17,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 955,
#               'latest.admissions.sat_scores.average.overall': 955,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 488,
#               'latest.admissions.sat_scores.midpoint.math': 457,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.7637,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.0625,
#               'latest.completion.completion_rate_4yr_150_aian': 0,
#               'latest.completion.completion_rate_4yr_150_asian': 0.3333,
#               'latest.completion.completion_rate_4yr_150_black': 0.2844,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.4286,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.3636,
#               'latest.completion.completion_rate_4yr_150nt': 0.2843,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.3015,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1600,
#               'latest.cost.otherexpense.offcampus': 5130,
#               'latest.cost.otherexpense.oncampus': 3392,
#               'latest.cost.otherexpense.withfamily': 5130,
#               'latest.cost.roomboard.offcampus': 7320,
#               'latest.cost.roomboard.oncampus': 6050,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 418,
#               'latest.cost.tuition.in_state': 11068,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Alabama State University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 8535,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.6315,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.1692,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 27,
#               'latest.admissions.act_scores.midpoint.math': 24,
#               'latest.admissions.act_scores.midpoint.writing': 8,
#               'latest.admissions.sat_scores.average.by_ope_id': 1244,
#               'latest.admissions.sat_scores.average.overall': 1244,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 610,
#               'latest.admissions.sat_scores.midpoint.math': 610,
#               'latest.admissions.sat_scores.midpoint.writing': 540,
#               'latest.aid.federal_loan_rate': 0.3454,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.6649,
#               'latest.completion.completion_rate_4yr_150_aian': 0.6207,
#               'latest.completion.completion_rate_4yr_150_asian': 0.7912,
#               'latest.completion.completion_rate_4yr_150_black': 0.5663,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.661,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0.625,
#               'latest.completion.completion_rate_4yr_150_white': 0.7468,
#               'latest.completion.completion_rate_4yr_150nt': 0.7223,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.7219,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 800,
#               'latest.cost.otherexpense.offcampus': 4670,
#               'latest.cost.otherexpense.oncampus': 4670,
#               'latest.cost.otherexpense.withfamily': 5742,
#               'latest.cost.roomboard.offcampus': 13934,
#               'latest.cost.roomboard.oncampus': 13934,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 1360,
#               'latest.cost.tuition.in_state': 11620,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'The University of Alabama',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 13731,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.8788,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.5493,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.1488,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.6667,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': 0,
#               'latest.completion.completion_rate_l4yr_150_black': 0.2462,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.5,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': 0.2033,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.219,
#               'latest.cost.booksupply': 1000,
#               'latest.cost.otherexpense.offcampus': 4360,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 4360,
#               'latest.cost.roomboard.offcampus': 10238,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 137,
#               'latest.cost.tuition.in_state': 4930,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Central Alabama Community College',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 1731,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.6094},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.455,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': None,
#               'latest.cost.otherexpense.offcampus': None,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': None,
#               'latest.cost.roomboard.offcampus': None,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': None,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Athens State University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 6761,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 20,
#               'latest.admissions.act_scores.midpoint.math': 19,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 1069,
#               'latest.admissions.sat_scores.average.overall': 1069,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 538,
#               'latest.admissions.sat_scores.midpoint.math': 518,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.5138,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.2273,
#               'latest.completion.completion_rate_4yr_150_aian': 0.4,
#               'latest.completion.completion_rate_4yr_150_asian': 0.2222,
#               'latest.completion.completion_rate_4yr_150_black': 0.3287,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.25,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_4yr_150_white': 0.3889,
#               'latest.completion.completion_rate_4yr_150nt': 0.3569,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.3307,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1200,
#               'latest.cost.otherexpense.offcampus': 3830,
#               'latest.cost.otherexpense.oncampus': 3830,
#               'latest.cost.otherexpense.withfamily': 3830,
#               'latest.cost.roomboard.offcampus': 10296,
#               'latest.cost.roomboard.oncampus': 7368,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 444,
#               'latest.cost.tuition.in_state': 8860,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Auburn University at Montgomery',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 7879,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.6627,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.2758,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': 8,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': 570,
#               'latest.aid.federal_loan_rate': 0.2869,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.6765,
#               'latest.completion.completion_rate_4yr_150_aian': 0.7917,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8321,
#               'latest.completion.completion_rate_4yr_150_black': 0.6898,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.7647,
#               'latest.completion.completion_rate_4yr_150_nhpi': 1,
#               'latest.completion.completion_rate_4yr_150_white': 0.8206,
#               'latest.completion.completion_rate_4yr_150nt': 0.8088,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.7982,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1200,
#               'latest.cost.otherexpense.offcampus': 6028,
#               'latest.cost.otherexpense.oncampus': 6028,
#               'latest.cost.otherexpense.withfamily': 6028,
#               'latest.cost.roomboard.offcampus': 14596,
#               'latest.cost.roomboard.oncampus': 14596,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 1066,
#               'latest.cost.tuition.in_state': 11826,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Auburn University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 17273,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.9243,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.7931,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 26,
#               'latest.admissions.act_scores.midpoint.math': 23,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 1214,
#               'latest.admissions.sat_scores.average.overall': 1214,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 580,
#               'latest.admissions.sat_scores.midpoint.math': 585,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.6785,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.7143,
#               'latest.completion.completion_rate_4yr_150_aian': 0.5,
#               'latest.completion.completion_rate_4yr_150_asian': 0.8,
#               'latest.completion.completion_rate_4yr_150_black': 0.5818,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0.6,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.7147,
#               'latest.completion.completion_rate_4yr_150nt': 0.6984,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.7033,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1000,
#               'latest.cost.otherexpense.offcampus': 4690,
#               'latest.cost.otherexpense.oncampus': 2770,
#               'latest.cost.otherexpense.withfamily': 4690,
#               'latest.cost.roomboard.offcampus': 8000,
#               'latest.cost.roomboard.oncampus': 13600,
#               'latest.cost.title_iv.private.all': 207,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': 20100,
#               'latest.school.degrees_awarded.highest': 3,
#               'latest.school.name': 'Birmingham-Southern College',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 10137,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.7891,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.2352,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.4,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': 1,
#               'latest.completion.completion_rate_l4yr_150_black': 0.1418,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.1154,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': 0.1667,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.1581,
#               'latest.cost.booksupply': 800,
#               'latest.cost.otherexpense.offcampus': 2000,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 2000,
#               'latest.cost.roomboard.offcampus': 5500,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 117,
#               'latest.cost.tuition.in_state': 3936,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Chattahoochee Valley Community College',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 1380,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.5733},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.6125,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': 0.0588,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': 0.2222,
#               'latest.completion.completion_rate_4yr_150nt': 0.1071,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.1225,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1500,
#               'latest.cost.otherexpense.offcampus': 6782,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 4747,
#               'latest.cost.roomboard.offcampus': 7792,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': 3,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': 17014,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'South University-Montgomery',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 9771,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.4348,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.3333,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.1968,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.3571,
#               'latest.completion.completion_rate_l4yr_150_aian': 0,
#               'latest.completion.completion_rate_l4yr_150_asian': 0.3,
#               'latest.completion.completion_rate_l4yr_150_black': 0.2785,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.32,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': 0.3032,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.2997,
#               'latest.cost.booksupply': 950,
#               'latest.cost.otherexpense.offcampus': 2696,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 2696,
#               'latest.cost.roomboard.offcampus': 5400,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 189,
#               'latest.cost.tuition.in_state': 4860,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Enterprise State Community College',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 3488,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.6252},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.2051,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.32,
#               'latest.completion.completion_rate_l4yr_150_aian': 0.4688,
#               'latest.completion.completion_rate_l4yr_150_asian': 0.1818,
#               'latest.completion.completion_rate_l4yr_150_black': 0.2166,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.25,
#               'latest.completion.completion_rate_l4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_l4yr_150_white': 0.26,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.2512,
#               'latest.cost.booksupply': 1500,
#               'latest.cost.otherexpense.offcampus': 4507,
#               'latest.cost.otherexpense.oncampus': 4407,
#               'latest.cost.otherexpense.withfamily': 4407,
#               'latest.cost.roomboard.offcampus': 6215,
#               'latest.cost.roomboard.oncampus': 5900,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 543,
#               'latest.cost.tuition.in_state': 4860,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Coastal Alabama Community College',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 2249,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.5813},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': 20,
#               'latest.admissions.act_scores.midpoint.math': 19,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': 1042,
#               'latest.admissions.sat_scores.average.overall': 1042,
#               'latest.admissions.sat_scores.midpoint.critical_reading': 550,
#               'latest.admissions.sat_scores.midpoint.math': 548,
#               'latest.admissions.sat_scores.midpoint.writing': 470,
#               'latest.aid.federal_loan_rate': 0.6022,
#               'latest.completion.completion_rate_4yr_150_2ormore': 0.3333,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': 0.25,
#               'latest.completion.completion_rate_4yr_150_black': 0.1293,
#               'latest.completion.completion_rate_4yr_150_hispanic': 0,
#               'latest.completion.completion_rate_4yr_150_nhpi': 0.3333,
#               'latest.completion.completion_rate_4yr_150_white': 0.2101,
#               'latest.completion.completion_rate_4yr_150nt': 0.1851,
#               'latest.completion.completion_rate_4yr_150nt_pooled': 0.2345,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1800,
#               'latest.cost.otherexpense.offcampus': 4400,
#               'latest.cost.otherexpense.oncampus': 4400,
#               'latest.cost.otherexpense.withfamily': 4400,
#               'latest.cost.roomboard.offcampus': 7900,
#               'latest.cost.roomboard.oncampus': 7900,
#               'latest.cost.title_iv.private.all': 224,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': 23490,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Faulkner University',
#               'latest.school.state_fips': 1,
#               'latest.school.tuition_revenue_per_fte': 13718,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.6238,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.4363,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
# ...
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': None,
#               'latest.cost.booksupply': 1018,
#               'latest.cost.otherexpense.offcampus': 1923,
#               'latest.cost.otherexpense.oncampus': 1923,
#               'latest.cost.otherexpense.withfamily': 1923,
#               'latest.cost.roomboard.offcampus': 8162,
#               'latest.cost.roomboard.oncampus': 9520,
#               'latest.cost.title_iv.private.all': 35,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': 34701,
#               'latest.school.degrees_awarded.highest': 4,
#               'latest.school.name': 'Prescott College',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 13202,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': 0.6699,
#               'latest.student.retention_rate.four_year.part_time_pooled': 0.5,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': 6,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.7014,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.5909,
#               'latest.completion.completion_rate_l4yr_150_aian': 0.6577,
#               'latest.completion.completion_rate_l4yr_150_asian': 0.6667,
#               'latest.completion.completion_rate_l4yr_150_black': 0.4842,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.6943,
#               'latest.completion.completion_rate_l4yr_150_nhpi': 0.4444,
#               'latest.completion.completion_rate_l4yr_150_white': 0.7342,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.6671,
#               'latest.cost.booksupply': None,
#               'latest.cost.otherexpense.offcampus': None,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': None,
#               'latest.cost.roomboard.offcampus': None,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': 348,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': None,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Refrigeration School Inc',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 15318,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.7843},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.0598,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.2,
#               'latest.completion.completion_rate_l4yr_150_aian': 0,
#               'latest.completion.completion_rate_l4yr_150_asian': 0,
#               'latest.completion.completion_rate_l4yr_150_black': 0,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.1034,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': 0.1176,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.0851,
#               'latest.cost.booksupply': 1464,
#               'latest.cost.otherexpense.offcampus': 3456,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 3456,
#               'latest.cost.roomboard.offcampus': 7552,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 69,
#               'latest.cost.tuition.in_state': 2070,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Rio Salado College',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 2634,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.3807},
#              {'latest.academics.program_reporter.programs_offered': 1,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.4,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': None,
#               'latest.completion.completion_rate_l4yr_150_aian': None,
#               'latest.completion.completion_rate_l4yr_150_asian': None,
#               'latest.completion.completion_rate_l4yr_150_black': None,
#               'latest.completion.completion_rate_l4yr_150_hispanic': None,
#               'latest.completion.completion_rate_l4yr_150_nhpi': None,
#               'latest.completion.completion_rate_l4yr_150_white': None,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 1,
#               'latest.cost.booksupply': None,
#               'latest.cost.otherexpense.offcampus': None,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': None,
#               'latest.cost.roomboard.offcampus': None,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': 16,
#               'latest.cost.title_iv.public.all': None,
#               'latest.cost.tuition.in_state': None,
#               'latest.school.degrees_awarded.highest': 1,
#               'latest.school.name': 'Roberto-Venn School of Luthiery',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 16987,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': None},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.0735,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.1875,
#               'latest.completion.completion_rate_l4yr_150_aian': 0,
#               'latest.completion.completion_rate_l4yr_150_asian': 0.1667,
#               'latest.completion.completion_rate_l4yr_150_black': 0.2083,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.1448,
#               'latest.completion.completion_rate_l4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_l4yr_150_white': 0.2074,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.1732,
#               'latest.cost.booksupply': 1464,
#               'latest.cost.otherexpense.offcampus': 10476,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 10476,
#               'latest.cost.roomboard.offcampus': 8496,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 114,
#               'latest.cost.tuition.in_state': 2070,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'Scottsdale Community College',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 2079,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.6548},
#              {'latest.academics.program_reporter.programs_offered': None,
#               'latest.admissions.act_scores.midpoint.english': None,
#               'latest.admissions.act_scores.midpoint.math': None,
#               'latest.admissions.act_scores.midpoint.writing': None,
#               'latest.admissions.sat_scores.average.by_ope_id': None,
#               'latest.admissions.sat_scores.average.overall': None,
#               'latest.admissions.sat_scores.midpoint.critical_reading': None,
#               'latest.admissions.sat_scores.midpoint.math': None,
#               'latest.admissions.sat_scores.midpoint.writing': None,
#               'latest.aid.federal_loan_rate': 0.0772,
#               'latest.completion.completion_rate_4yr_150_2ormore': None,
#               'latest.completion.completion_rate_4yr_150_aian': None,
#               'latest.completion.completion_rate_4yr_150_asian': None,
#               'latest.completion.completion_rate_4yr_150_black': None,
#               'latest.completion.completion_rate_4yr_150_hispanic': None,
#               'latest.completion.completion_rate_4yr_150_nhpi': None,
#               'latest.completion.completion_rate_4yr_150_white': None,
#               'latest.completion.completion_rate_4yr_150nt': None,
#               'latest.completion.completion_rate_4yr_150nt_pooled': None,
#               'latest.completion.completion_rate_l4yr_150_2ormore': 0.125,
#               'latest.completion.completion_rate_l4yr_150_aian': 0,
#               'latest.completion.completion_rate_l4yr_150_asian': 0.3333,
#               'latest.completion.completion_rate_l4yr_150_black': 0.1957,
#               'latest.completion.completion_rate_l4yr_150_hispanic': 0.1429,
#               'latest.completion.completion_rate_l4yr_150_nhpi': 0,
#               'latest.completion.completion_rate_l4yr_150_white': 0.2444,
#               'latest.completion.completion_rate_less_than_4yr_150nt': 0.1632,
#               'latest.cost.booksupply': 1464,
#               'latest.cost.otherexpense.offcampus': 10476,
#               'latest.cost.otherexpense.oncampus': None,
#               'latest.cost.otherexpense.withfamily': 10476,
#               'latest.cost.roomboard.offcampus': 8496,
#               'latest.cost.roomboard.oncampus': None,
#               'latest.cost.title_iv.private.all': None,
#               'latest.cost.title_iv.public.all': 121,
#               'latest.cost.tuition.in_state': 2070,
#               'latest.school.degrees_awarded.highest': 2,
#               'latest.school.name': 'South Mountain Community College',
#               'latest.school.state_fips': 4,
#               'latest.school.tuition_revenue_per_fte': 1223,
#               'latest.student.enrollment.all': None,
#               'latest.student.retention_rate.four_year.full_time_pooled': None,
#               'latest.student.retention_rate.four_year.part_time_pooled': None,
#               'latest.student.retention_rate.lt_four_year.full_time_pooled': 0.5714}]}

# %%
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "latest.root.id,latest.root.location.lon,latest.root.location.lat,latest.school.name,"+
    
    #school city / classifications
    "latest.school.city,latest.school.carnegie_undergrad,latest.school.carnegie_size_setting,"+
    "latest.school.carnegie_basic"
    
    #costs
    "latest.cost.attendance.academic_year,latest.cost.attendance.program_year"+
    
    #fafsa
    "latest.student.fafsa_sent.overall,"+
    
    #completion time by program
    "latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion,"+
    "latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion,"+
    "latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion,"+
    "latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion,"+
    "latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion,"+
    "latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion,"+
    
    #average net price
    "latest.cost.avg_net_price.public,latest.cost.avg_net_price.private,latest.cost.avg_net_price.other_academic_year,"+
    "latest.cost.avg_net_price.program_year,latest.cost.net_price.public.by_income_level.75001-110000,"+
    "latest.cost.net_price.program_reporter.by_income_level.75001-110000,latest.cost.net_price.private.by_income_level.75001-110000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000,latest.cost.net_price.public.by_income_level.75000-plus,"+
    "latest.cost.net_price.program_reporter.by_income_level.75000-plus,latest.cost.net_price.private.by_income_level.75000-plus,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus,latest.cost.net_price.public.by_income_level.48001-75000,"+
    "latest.cost.net_price.program_reporter.by_income_level.48001-75000,latest.cost.net_price.private.by_income_level.48001-75000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000,latest.cost.net_price.public.by_income_level.30001-75000,"+
    "latest.cost.net_price.program_reporter.by_income_level.30001-75000,latest.cost.net_price.private.by_income_level.30001-75000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000,latest.cost.net_price.public.by_income_level.30001-48000,"+
    "latest.cost.net_price.program_reporter.by_income_level.30001-48000,latest.cost.net_price.private.by_income_level.30001-48000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000,latest.cost.net_price.public.by_income_level.110001-plus,"+
    "latest.cost.net_price.program_reporter.by_income_level.110001-plus,latest.cost.net_price.private.by_income_level.110001-plus,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus,latest.cost.net_price.public.by_income_level.0-48000,"+
    "latest.cost.net_price.program_reporter.by_income_level.0-48000,latest.cost.net_price.private.by_income_level.0-48000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.0-48000,latest.cost.net_price.public.by_income_level.0-30000,"+
    "latest.cost.net_price.program_reporter.by_income_level.0-30000,latest.cost.net_price.private.by_income_level.0-30000,"+
    "latest.cost.net_price.other_acad_calendar.by_income_level.0-30000,"+
    
    #admission rate
    "latest.admissions.admission_rate.overall"
}

response = requests.get(url, params=params)
response = response.json()
pprint(response)
# Out:
# {'metadata': {'page': 0, 'per_page': 100, 'total': 6543},
#  'results': [{'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.716,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 13057,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 12177,
#               'latest.cost.net_price.public.by_income_level.0-48000': 12210,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 18857,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 12300,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 13424,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 15508,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 17399,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 16707,
#               'latest.school.carnegie_size_setting': 14,
#               'latest.school.carnegie_undergrad': 10,
#               'latest.school.city': 'Normal',
#               'latest.school.name': 'Alabama A & M University'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.8854,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 16585,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 13862,
#               'latest.cost.net_price.public.by_income_level.0-48000': 14431,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 20054,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 15370,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 16038,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 16847,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 19441,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 18230,
#               'latest.school.carnegie_size_setting': 15,
#               'latest.school.carnegie_undergrad': 9,
#               'latest.school.city': 'Birmingham',
#               'latest.school.name': 'University of Alabama at Birmingham'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': None,
#               'latest.cost.net_price.public.by_income_level.0-48000': None,
#               'latest.cost.net_price.public.by_income_level.110001-plus': None,
#               'latest.cost.net_price.public.by_income_level.30001-48000': None,
#               'latest.cost.net_price.public.by_income_level.30001-75000': None,
#               'latest.cost.net_price.public.by_income_level.48001-75000': None,
#               'latest.cost.net_price.public.by_income_level.75000-plus': None,
#               'latest.cost.net_price.public.by_income_level.75001-110000': None,
#               'latest.school.carnegie_size_setting': 6,
#               'latest.school.carnegie_undergrad': 5,
#               'latest.school.city': 'Montgomery',
#               'latest.school.name': 'Amridge University'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.7367,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 17250,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 14654,
#               'latest.cost.net_price.public.by_income_level.0-48000': 14651,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 19423,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 14646,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 16919,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 18572,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 19333,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 19206,
#               'latest.school.carnegie_size_setting': 13,
#               'latest.school.carnegie_undergrad': 15,
#               'latest.school.city': 'Huntsville',
#               'latest.school.name': 'University of Alabama in Huntsville'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.9799,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 13593,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 12877,
#               'latest.cost.net_price.public.by_income_level.0-48000': 13180,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 21938,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 14170,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 14127,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 13992,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 21072,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 20568,
#               'latest.school.carnegie_size_setting': 14,
#               'latest.school.carnegie_undergrad': 10,
#               'latest.school.city': 'Montgomery',
#               'latest.school.name': 'Alabama State University'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.789,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 21534,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 18338,
#               'latest.cost.net_price.public.by_income_level.0-48000': 18883,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 24948,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 20121,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 21041,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 21957,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 24553,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 23830,
#               'latest.school.carnegie_size_setting': 16,
#               'latest.school.carnegie_undergrad': 12,
#               'latest.school.city': 'Tuscaloosa',
#               'latest.school.name': 'The University of Alabama'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 8628,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 6837,
#               'latest.cost.net_price.public.by_income_level.0-48000': 7367,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 12845,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 8734,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 9227,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 9837,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 12623,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 12453,
#               'latest.school.carnegie_size_setting': 2,
#               'latest.school.carnegie_undergrad': 1,
#               'latest.school.city': 'Alexander City',
#               'latest.school.name': 'Central Alabama Community College'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': None,
#               'latest.cost.net_price.public.by_income_level.0-48000': None,
#               'latest.cost.net_price.public.by_income_level.110001-plus': None,
#               'latest.cost.net_price.public.by_income_level.30001-48000': None,
#               'latest.cost.net_price.public.by_income_level.30001-75000': None,
#               'latest.cost.net_price.public.by_income_level.48001-75000': None,
#               'latest.cost.net_price.public.by_income_level.75000-plus': None,
#               'latest.cost.net_price.public.by_income_level.75001-110000': None,
#               'latest.school.carnegie_size_setting': 9,
#               'latest.school.carnegie_undergrad': 5,
#               'latest.school.city': 'Athens',
#               'latest.school.name': 'Athens State University'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.968,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 13689,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 12565,
#               'latest.cost.net_price.public.by_income_level.0-48000': 12912,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 15387,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 13773,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 14352,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 15661,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 16148,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 17249,
#               'latest.school.carnegie_size_setting': 13,
#               'latest.school.carnegie_undergrad': 7,
#               'latest.school.city': 'Montgomery',
#               'latest.school.name': 'Auburn University at Montgomery'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.7118,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 23258,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 16701,
#               'latest.cost.net_price.public.by_income_level.0-48000': 17844,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 26836,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 19313,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 20987,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 22379,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 26226,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 24989,
#               'latest.school.carnegie_size_setting': 15,
#               'latest.school.carnegie_undergrad': 14,
#               'latest.school.city': 'Auburn',
#               'latest.school.name': 'Auburn University'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': 0.6591,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': 21098,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': 17500,
#               'latest.cost.net_price.private.by_income_level.0-48000': 17414,
#               'latest.cost.net_price.private.by_income_level.110001-plus': 23073,
#               'latest.cost.net_price.private.by_income_level.30001-48000': 17302,
#               'latest.cost.net_price.private.by_income_level.30001-75000': 17452,
#               'latest.cost.net_price.private.by_income_level.48001-75000': 17602,
#               'latest.cost.net_price.private.by_income_level.75000-plus': 22796,
#               'latest.cost.net_price.private.by_income_level.75001-110000': 21925,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': None,
#               'latest.cost.net_price.public.by_income_level.0-48000': None,
#               'latest.cost.net_price.public.by_income_level.110001-plus': None,
#               'latest.cost.net_price.public.by_income_level.30001-48000': None,
#               'latest.cost.net_price.public.by_income_level.30001-75000': None,
#               'latest.cost.net_price.public.by_income_level.48001-75000': None,
#               'latest.cost.net_price.public.by_income_level.75000-plus': None,
#               'latest.cost.net_price.public.by_income_level.75001-110000': None,
#               'latest.school.carnegie_size_setting': 11,
#               'latest.school.carnegie_undergrad': 12,
#               'latest.school.city': 'Birmingham',
#               'latest.school.name': 'Birmingham-Southern College'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 3557,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 3166,
#               'latest.cost.net_price.public.by_income_level.0-48000': 2939,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 5320,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 2435,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 3680,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 5617,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 5621,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 5658,
#               'latest.school.carnegie_size_setting': 2,
#               'latest.school.carnegie_undergrad': 2,
#               'latest.school.city': 'Phenix City',
#               'latest.school.name': 'Chattahoochee Valley Community College'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': 18772,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
# ...
#               'latest.cost.net_price.public.by_income_level.30001-75000': None,
#               'latest.cost.net_price.public.by_income_level.48001-75000': None,
#               'latest.cost.net_price.public.by_income_level.75000-plus': None,
#               'latest.cost.net_price.public.by_income_level.75001-110000': None,
#               'latest.school.carnegie_size_setting': 2,
#               'latest.school.carnegie_undergrad': 4,
#               'latest.school.city': 'Phoenix',
#               'latest.school.name': 'Refrigeration School Inc'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 9226,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 8337,
#               'latest.cost.net_price.public.by_income_level.0-48000': 8564,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 13285,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 9334,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 10090,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 11727,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 13010,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 12460,
#               'latest.school.carnegie_size_setting': 4,
#               'latest.school.carnegie_undergrad': 1,
#               'latest.school.city': 'Tempe',
#               'latest.school.name': 'Rio Salado College'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': 5,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': 23078,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': 23078,
#               'latest.cost.net_price.private.by_income_level.0-48000': 23078,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': None,
#               'latest.cost.net_price.public.by_income_level.0-48000': None,
#               'latest.cost.net_price.public.by_income_level.110001-plus': None,
#               'latest.cost.net_price.public.by_income_level.30001-48000': None,
#               'latest.cost.net_price.public.by_income_level.30001-75000': None,
#               'latest.cost.net_price.public.by_income_level.48001-75000': None,
#               'latest.cost.net_price.public.by_income_level.75000-plus': None,
#               'latest.cost.net_price.public.by_income_level.75001-110000': None,
#               'latest.school.carnegie_size_setting': -2,
#               'latest.school.carnegie_undergrad': -2,
#               'latest.school.city': 'Phoenix',
#               'latest.school.name': 'Roberto-Venn School of Luthiery'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 11286,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 10279,
#               'latest.cost.net_price.public.by_income_level.0-48000': 10381,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 16150,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 10667,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 11786,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 13501,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 15077,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 14719,
#               'latest.school.carnegie_size_setting': 3,
#               'latest.school.carnegie_undergrad': 1,
#               'latest.school.city': 'Scottsdale',
#               'latest.school.name': 'Scottsdale Community College'},
#              {'latest.academics.program_reporter.program_1.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_2.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_3.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_4.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_5.cip_6_digit.avg_month_completion': None,
#               'latest.academics.program_reporter.program_6.cip_6_digit.avg_month_completion': None,
#               'latest.admissions.admission_rate.overall': None,
#               'latest.cost.avg_net_price.other_academic_year': None,
#               'latest.cost.avg_net_price.private': None,
#               'latest.cost.avg_net_price.program_year': None,
#               'latest.cost.avg_net_price.public': 10040,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-30000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.0-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.110001-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-48000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.30001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.48001-75000': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75000-plus': None,
#               'latest.cost.net_price.other_acad_calendar.by_income_level.75001-110000': None,
#               'latest.cost.net_price.private.by_income_level.0-30000': None,
#               'latest.cost.net_price.private.by_income_level.0-48000': None,
#               'latest.cost.net_price.private.by_income_level.110001-plus': None,
#               'latest.cost.net_price.private.by_income_level.30001-48000': None,
#               'latest.cost.net_price.private.by_income_level.30001-75000': None,
#               'latest.cost.net_price.private.by_income_level.48001-75000': None,
#               'latest.cost.net_price.private.by_income_level.75000-plus': None,
#               'latest.cost.net_price.private.by_income_level.75001-110000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-30000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.0-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.110001-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-48000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.30001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.48001-75000': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75000-plus': None,
#               'latest.cost.net_price.program_reporter.by_income_level.75001-110000': None,
#               'latest.cost.net_price.public.by_income_level.0-30000': 9486,
#               'latest.cost.net_price.public.by_income_level.0-48000': 9605,
#               'latest.cost.net_price.public.by_income_level.110001-plus': 14440,
#               'latest.cost.net_price.public.by_income_level.30001-48000': 9944,
#               'latest.cost.net_price.public.by_income_level.30001-75000': 10207,
#               'latest.cost.net_price.public.by_income_level.48001-75000': 10594,
#               'latest.cost.net_price.public.by_income_level.75000-plus': 14072,
#               'latest.cost.net_price.public.by_income_level.75001-110000': 13950,
#               'latest.school.carnegie_size_setting': 2,
#               'latest.school.carnegie_undergrad': 1,
#               'latest.school.city': 'Phoenix',
#               'latest.school.name': 'South Mountain Community College'}]}
